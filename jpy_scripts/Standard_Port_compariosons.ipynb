# %%
import numpy as np
import azapy as az

print(f"azapy version {az.version()} >= 1.2.0")
# Out:
# azapy version 1.2.6 >= 1.2.0

# %%
mktdir = "../MkTdata"

sdate = "2012-01-01"
edate = "today"

symb = ['GLD', 'TLT', 'XLV', 'IHI', 'SPY',]

mktdata = az.readMkT(symb, sdate=sdate, edate=edate, file_dir=mktdir)
# Out:
# read GLD data from file
# read TLT data from file
# read XLV data from file
# read IHI data from file
# read SPY data from file
#
# Request between 2012-01-03 : 2026-05-05
#                     GLD         TLT         XLV         IHI         SPY
# source            yahoo       yahoo       yahoo       yahoo       yahoo
# force             False       False       False       False       False
# save               True        True        True        True        True
# file_dir     ../MkTdata  ../MkTdata  ../MkTdata  ../MkTdata  ../MkTdata
# file_format         csv         csv         csv         csv         csv
# api_key            None        None        None        None        None
# nrow               3605        3605        3605        3605        3605
# sdate        2012-01-03  2012-01-03  2012-01-03  2012-01-03  2012-01-03
# edate        2026-05-05  2026-05-05  2026-05-05  2026-05-05  2026-05-05
# error                No          No          No          No          No
# extraction time 0.307 s

# %%
alpha = np.array([0.95, 0.925, 0.9])
coef = np.full(len(alpha), 1/len(alpha))

# set Port_CVaR class
p4 = az.Port_CVaR(mktdata, pname='mCVaRPort')

# %%
rtypes = ["MaxDiverse", "MinRisk", "Sharpe", "InvNrisk", "InvNdrr", "InvNdiverse"]
hlength = 3.25

port = []
for rty in rtypes:
    port4 = p4.set_model(alpha=alpha, rtype=rty, hlength=hlength)  
    port4.columns = [rty]
    port.append(port4)

# %%
p5 = az.Port_ConstW(mktdata, pname="EWP")
port5 = p5.set_model()
port.append(port5)

# %%
pp = az.Port_Simple(port)
pp.set_model()
_ = pp.port_view_all(componly=True, 
     title="mCVaR Portfolios - Relative Performance", 
     xlabel="year", fancy=True)

# %%
pp.port_perf(componly=True, fancy=True)
# Out:
#                 RR     DD     RoMaD     DD_date    DD_start      DD_end  \
# symbol
# Sharpe       12.24 -21.39  0.572396  2022-09-27  2021-11-12  2024-02-22
# InvNrisk     12.98 -23.37  0.555318  2022-09-27  2021-09-03  2024-03-27
# InvNdiverse  11.06 -24.95  0.443215  2022-09-27  2021-09-03  2024-07-16
# EWP           9.29 -22.14  0.419848  2022-10-20  2021-12-30  2024-06-20
# MinRisk       7.78 -19.75  0.394018  2022-10-20  2021-12-31  2024-03-07
# InvNdrr       6.99 -25.11  0.278286  2022-10-20  2021-12-27  2024-09-13
# MaxDiverse    6.61 -26.08  0.253517  2022-10-20  2021-12-27  2025-09-11
#
#              DD_days
# symbol
# Sharpe           832
# InvNrisk         936
# InvNdiverse     1047
# EWP              903
# MinRisk          797
# InvNdrr          991
# MaxDiverse      1354
