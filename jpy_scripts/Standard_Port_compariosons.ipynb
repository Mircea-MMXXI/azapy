# %%
import numpy as np
import azapy as az

print(f"azapy version {az.version()} >= 1.2.0")
# Out:
# azapy version 1.2.5 >= 1.2.0

# %%
mktdir = "../MkTdata"

sdate = "2012-01-01"
edate = "2022-05-11"
edate = 'today'

symb = ['GLD', 'TLT', 'XLV', 'IHI', 'VGT',]

mktdata = az.readMkT(symb, sdate=sdate, edate=edate, file_dir=mktdir)
# Out:
# read GLD data from file
# read TLT data from file
# read XLV data from file
# read IHI data from file
# read VGT data from file
#
# Request between 2012-01-03 : 2024-07-03
#                     GLD         TLT         XLV         IHI         VGT
# source            yahoo       yahoo       yahoo       yahoo       yahoo
# force             False       False       False       False       False
# save               True        True        True        True        True
# file_dir     ../MkTdata  ../MkTdata  ../MkTdata  ../MkTdata  ../MkTdata
# file_format         csv         csv         csv         csv         csv
# api_key            None        None        None        None        None
# nrow               3145        3145        3145        3145        3145
# sdate        2012-01-03  2012-01-03  2012-01-03  2012-01-03  2012-01-03
# edate        2024-07-03  2024-07-03  2024-07-03  2024-07-03  2024-07-03
# error                No          No          No          No          No
# extraction time 0.194 s

# %%
alpha = np.array([0.95, 0.925, 0.9])
coef = np.full(len(alpha), 1/len(alpha))

# set Port_CVaR class
p4 = az.Port_CVaR(mktdata, pname='mCVaRPort')

# %%
rtypes = ["MaxDiverse", "MinRisk", "Sharpe", "InvNrisk", "InvNdrr", "InvNdiverse"]
hlength = 3.25

port = []
for rty in rtypes:
    port4 = p4.set_model(alpha=alpha, rtype=rty, hlength=hlength)  
    port4.columns = [rty]
    port.append(port4)

# %%
p5 = az.Port_ConstW(mktdata, pname="EWP")
port5 = p5.set_model()
port.append(port5)

# %%
pp = az.Port_Simple(port)
pp.set_model()
_ = pp.port_view_all(componly=True, 
     title="mCVaR Portfolios - Relative Performance", 
     xlabel="year", fancy=True)

# %%
pp.port_perf(componly=True, fancy=True)
# Out:
#                 RR     DD     RoMaD     DD_date    DD_start      DD_end  \
# symbol
# InvNrisk     12.43 -22.76  0.546000  2022-09-26  2021-11-18  2024-02-15
# Sharpe       10.46 -22.32  0.468510  2022-09-26  2021-11-18  2024-06-10
# InvNdiverse  13.07 -27.99  0.467125  2022-10-14  2021-12-27  2024-06-14
# EWP          10.83 -23.99  0.451487  2022-10-20  2021-12-30  2024-03-07
# MinRisk       8.72 -19.46  0.447894  2022-10-20  2021-12-30  2024-03-06
# MaxDiverse    8.94 -21.67  0.412382  2022-10-20  2021-12-30         NaN
# InvNdrr       9.67 -24.57  0.393728  2022-10-20  2021-12-27         NaN
#
#              DD_days
# symbol
# InvNrisk         819
# Sharpe           935
# InvNdiverse      900
# EWP              798
# MinRisk          797
# MaxDiverse       916
# InvNdrr          919
