# %% [markdown]
# # Sharpe optimal portfolio - comparisons
#
# This example compares the performance of several risk-Sharpe optimal portfolios.
#
# The CVaR, SMCR, EVaR, MAD, LSD, BTAD, BTSD, GINI, SD and MV risk-based portfolios are considered. We use the `rtype=Sharpe` optimization flag with a risk-free rate of 0 (default value).
#
# We start by importing **azapy** and other useful packages.

# %%
import sys
sys.path.append("..")
import azapy as az

print(f"azapy version {az.version()}")
# Out:
# azapy version 1.2.3

# %% [markdown]
# ### Collect historical market data
#
# - `symb` is the list of stock symbols (portfolio components).
# - `sdate` and `edate` are the start and end dates of historical time-series.
# - `force=True` get historical market data directly from the provider (in this case yahoo)
# - `save=False` the historical market data is not saved
#
# >For more information see https://azapy.readthedocs.io/en/latest/.

# %%
symb = ['GLD', 'TLT', 'XLV', 'VGT', 'VHT']

sdate = "2012-01-01"
edate = "today"

mktdata = az.readMkT(symb, sdate=sdate, edate=edate, force=True, save=False)
# Out:
# get GLD from yahoo only
# get TLT from yahoo only
# get XLV from yahoo only
# get VGT from yahoo only
# get VHT from yahoo only
#
# Request between 2012-01-03 : 2024-03-28
#                     GLD         TLT         XLV         VGT         VHT
# source            yahoo       yahoo       yahoo       yahoo       yahoo
# force              True        True        True        True        True
# save              False       False       False       False       False
# file_dir         outDir      outDir      outDir      outDir      outDir
# file_format         csv         csv         csv         csv         csv
# api_key            None        None        None        None        None
# nrow               3079        3079        3079        3079        3079
# sdate        2012-01-03  2012-01-03  2012-01-03  2012-01-03  2012-01-03
# edate        2024-03-28  2024-03-28  2024-03-28  2024-03-28  2024-03-28
# error                No          No          No          No          No
# extraction time 2.057 s

# %% [markdown]
# ### Set scenarios model parameters
#
# Since we plan to run many scenarios, it is useful to organize their model parameters in a dictionary.
# The keys are the portfolio names, and the values are the model parameters organized also as dictionaries:
# - 'type' : is the portfolio class used in the simulation,
# - 'm_param' : is a dictionary with parameters for `set_model` functions.
#
# Note that:
# - `'P_N'` is the reference equal weighted portfolio,
# - `'P_CVaR'` is the mCVaR optimal portfolio with confidence levels `alpha_CVaR` equal weighted,
# - `'P_SMCR'` is the mSMCR optimal portfolio with confidence levels `alpha_SMCR` equal weighted,
# - `'P_EVaR'` is the mEVaR optimal portfolio with confidence levels `alpha_EVaR` equal weighted.
# - `'P_MAD'` is the mMAD optimal portfolio with weights `coef_MAD`,
# - `'P_LSD'` is the mLSD optimal portfolio with weights `coef_LSD`,
# - `'P_Omega'` is the mBTAD optimal portfolio with threshold levels `alpha_BTAD` equal weighted,
# - `'P_Sortino'` is the mBTSD optimal portfolio with threshold levels `alpha_BTSD` equal weighted,
# - `'P_GINI'` is the Gini optimal portfolio (commented out in `models` dictionary below, for speed reasons),
# - `'P_MV'` is the MV optimal portfolio,
# - `'P_SD'` is the SD optimal portfolio.
#
#
# - In all cases the optimization type is set to `rtype='Sharpe'` (optimal portfolio with the same risk profile as the equal weighted portfolio) with risk-free rate mu0=0.
# - The `'hlength'` parameter (the length of historical data used in weights calibration) is set to 3.25 years except for `'P_GINI'` where it is set to 1.25 years (for computational speed convenience).
#
# > Note:
# > - mBTAD-Sharpe ratio is called Omega ratio
# > - mBTSD-Sharpe ratio is called Sortino ratio
# > - MV-Sharpe ratio is different than (SD) Sharp ratio

# %%
rtype = 'Sharpe'
alpha_CVaR = [0.95, 0.90, 0.85]
alpha_SMCR = [0.9, 0.80]
coef_MAD = [1./3.] * 3
coef_LSD = [1./3.] * 3
alpha_BTAD = [-0.01, 0]
alpha_BTSD = [-0.01, 0]
alpha_EVaR = [0.75, 0.65]
hlength = 1.25

models = {'P_CVaR-Sharpe': {'type': 'Port_CVaR', 'm_param': {'alpha': alpha_CVaR, 'rtype': rtype, 'hlength': hlength}},
          'P_SMCR-Sharpe': {'type': 'Port_SMCR', 'm_param': {'alpha': alpha_SMCR, 'rtype': rtype, 'hlength': hlength}},
          'P_EVaR-Sharpe': {'type': 'Port_EVaR', 'm_param': {'alpha': alpha_EVaR, 'rtype': rtype, 'hlength': hlength}},
          'P_MAD-Sharpe': {'type': 'Port_MAD', 'm_param': {'coef': coef_MAD, 'rtype': rtype, 'hlength': hlength}},
          'P_LSD-Sharpe': {'type': 'Port_LSD', 'm_param': {'coef': coef_LSD, 'rtype': rtype, 'hlength': hlength}},
          'P_Omega': {'type': 'Port_BTAD', 'm_param': {'alpha': alpha_BTAD, 'rtype': rtype, 'hlength': hlength}},
          'P_Sortino': {'type': 'Port_BTSD', 'm_param': {'alpha': alpha_BTSD, 'rtype': rtype, 'hlength': hlength}},
          #'P_GINI-Sharpe': {'type': 'Port_GINI', 'm_param': {'rtype': rtype, 'hlength': 1.25}},
          'P_MV-Sharpe': {'type': 'Port_MV', 'm_param': {'rtype': rtype, 'hlength': hlength}},
          'P_Sharpe': {'type': 'Port_SD', 'm_param': {'rtype': rtype, 'hlength': hlength}},
          'P_N': {'type': 'Port_ConstW', 'm_param': {'ww': None}}}

# %% [markdown]
# ### Main computation loop
#
# - `port` is a list containing the simulated time-series. We will use it to setup a simple portfolio *(see the documentation for `Port_Simple` class)*. It is a very convenient way to facilitate the visual and numerical comparisons between these portfolio performances.
# - `pp` is a dictionary holding the portfolio objects. They may be used later for further analytical inquires.

# %%
port = []
pp = {}
for key, val in models.items():
    ppz = getattr(az, val['type'])
    pp_ = ppz(mktdata, pname=key)
    pp[key] = pp_
    port_ = pp_.set_model(**val['m_param'])
    port.append(port_)

# %% [markdown]
# ### Prepare the results for comparisons
#
# Build a `Port_Simple` class holding all the computed portfolios as components. We use this structure to build comparative graphical and numerical performance reports. The aggregated portfolio of portfolios time-series will be neglected.
#
# >Note the call to `set_model` method that is a must.
#
# >Observation: `Port_Simple` is the class that supports the back testing of "Buy and Hold" portfolio (_see its documentation_).
# It also can be used as a tool to compare the performance of multiple portfolios. Here we use it in this latter capacity.

# %%
ps = az.Port_Simple(port, col='close', pname='ALL')
_ = ps.set_model()

# %% [markdown]
# ### Time-series visualization
#
# We used the flag `componly=True` to plot only the portfolio components.

# %%
_ = ps.port_view_all(componly=True, fancy=True, title="Relative performance")

# %% [markdown]
# ### Portfolio performances

# %%
ps.port_perf(componly=True, fancy=True)
# Out:
#                   RR     DD     RoMaD     DD_date    DD_start      DD_end  \
# symbol
# P_MV-Sharpe     9.26 -17.19  0.538737  2022-09-30  2021-12-30  2024-03-01
# P_N            10.07 -21.29  0.472815  2022-10-20  2021-12-30  2024-02-07
# P_Sortino       9.33 -20.87  0.447253  2018-12-24  2018-10-03  2019-08-08
# P_CVaR-Sharpe   9.87 -23.95  0.412110  2018-12-24  2018-10-03  2019-08-27
# P_LSD-Sharpe    9.83 -23.95  0.410444  2018-12-24  2018-10-03  2019-09-04
# P_EVaR-Sharpe   9.66 -23.95  0.403199  2018-12-24  2018-10-03  2019-12-27
# P_Sharpe        9.50 -23.95  0.396761  2018-12-24  2018-10-03  2019-08-14
# P_MAD-Sharpe    9.08 -23.63  0.384158  2018-12-24  2018-10-03  2019-08-15
# P_SMCR-Sharpe   8.93 -23.95  0.372725  2018-12-24  2018-10-03  2020-01-02
# P_Omega         8.48 -22.85  0.371106  2018-12-24  2018-10-03  2019-08-28
#
#                DD_days
# symbol
# P_MV-Sharpe        792
# P_N                769
# P_Sortino          309
# P_CVaR-Sharpe      328
# P_LSD-Sharpe       336
# P_EVaR-Sharpe      450
# P_Sharpe           315
# P_MAD-Sharpe       316
# P_SMCR-Sharpe      456
# P_Omega            329

# %% [markdown]
# ### Annual returns
#
# Note the best and worst performer each year.
#
# > The flags `withcomp=True` includes the portfolios components while the flag `componly=True` excludes the aggregated portfolio of portfolios.

# %%
ps.port_annual_returns(withcomp=True, componly=True, fancy=True)
# Out:
# <style type="text/css">
# #T_5275e_row0_col0, #T_5275e_row0_col1, #T_5275e_row0_col2, #T_5275e_row0_col3, #T_5275e_row0_col4, #T_5275e_row0_col5, #T_5275e_row0_col6, #T_5275e_row0_col7, #T_5275e_row0_col8, #T_5275e_row0_col9, #T_5275e_row3_col6, #T_5275e_row7_col0, #T_5275e_row7_col1, #T_5275e_row7_col2, #T_5275e_row7_col3, #T_5275e_row7_col4, #T_5275e_row7_col5, #T_5275e_row7_col6, #T_5275e_row7_col7, #T_5275e_row7_col8, #T_5275e_row7_col9 {
#   color: red;
# }
# #T_5275e_row1_col0, #T_5275e_row1_col1, #T_5275e_row1_col2, #T_5275e_row1_col3, #T_5275e_row1_col4, #T_5275e_row1_col5, #T_5275e_row1_col6, #T_5275e_row1_col7, #T_5275e_row1_col8, #T_5275e_row1_col9, #T_5275e_row2_col0, #T_5275e_row2_col1, #T_5275e_row2_col2, #T_5275e_row2_col3, #T_5275e_row2_col4, #T_5275e_row2_col5, #T_5275e_row2_col6, #T_5275e_row2_col7, #T_5275e_row2_col8, #T_5275e_row2_col9, #T_5275e_row3_col0, #T_5275e_row3_col1, #T_5275e_row3_col2, #T_5275e_row3_col3, #T_5275e_row3_col4, #T_5275e_row3_col5, #T_5275e_row3_col7, #T_5275e_row3_col8, #T_5275e_row3_col9, #T_5275e_row4_col0, #T_5275e_row4_col1, #T_5275e_row4_col2, #T_5275e_row4_col3, #T_5275e_row4_col4, #T_5275e_row4_col5, #T_5275e_row4_col6, #T_5275e_row4_col7, #T_5275e_row4_col8, #T_5275e_row4_col9, #T_5275e_row5_col0, #T_5275e_row5_col1, #T_5275e_row5_col2, #T_5275e_row5_col3, #T_5275e_row5_col4, #T_5275e_row5_col5, #T_5275e_row5_col6, #T_5275e_row5_col7, #T_5275e_row5_col8, #T_5275e_row5_col9, #T_5275e_row6_col0, #T_5275e_row6_col1, #T_5275e_row6_col2, #T_5275e_row6_col3, #T_5275e_row6_col4, #T_5275e_row6_col5, #T_5275e_row6_col6, #T_5275e_row6_col7, #T_5275e_row6_col8, #T_5275e_row6_col9, #T_5275e_row8_col0, #T_5275e_row8_col1, #T_5275e_row8_col2, #T_5275e_row8_col3, #T_5275e_row8_col4, #T_5275e_row8_col5, #T_5275e_row8_col6, #T_5275e_row8_col7, #T_5275e_row8_col8, #T_5275e_row8_col9, #T_5275e_row9_col0, #T_5275e_row9_col1, #T_5275e_row9_col2, #T_5275e_row9_col3, #T_5275e_row9_col4, #T_5275e_row9_col5, #T_5275e_row9_col6, #T_5275e_row9_col7, #T_5275e_row9_col8, #T_5275e_row9_col9 {
#   color: black;
# }
# </style>
# <table id="T_5275e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th id="T_5275e_level0_col0" class="col_heading level0 col0" >P_CVaR-Sharpe</th>
#       <th id="T_5275e_level0_col1" class="col_heading level0 col1" >P_EVaR-Sharpe</th>
#       <th id="T_5275e_level0_col2" class="col_heading level0 col2" >P_LSD-Sharpe</th>
#       <th id="T_5275e_level0_col3" class="col_heading level0 col3" >P_MAD-Sharpe</th>
#       <th id="T_5275e_level0_col4" class="col_heading level0 col4" >P_MV-Sharpe</th>
#       <th id="T_5275e_level0_col5" class="col_heading level0 col5" >P_N</th>
#       <th id="T_5275e_level0_col6" class="col_heading level0 col6" >P_Omega</th>
#       <th id="T_5275e_level0_col7" class="col_heading level0 col7" >P_SMCR-Sharpe</th>
#       <th id="T_5275e_level0_col8" class="col_heading level0 col8" >P_Sharpe</th>
#       <th id="T_5275e_level0_col9" class="col_heading level0 col9" >P_Sortino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5275e_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_5275e_row0_col0" class="data row0 col0" >-8.13%</td>
#       <td id="T_5275e_row0_col1" class="data row0 col1" >-7.67%</td>
#       <td id="T_5275e_row0_col2" class="data row0 col2" >-8.11%</td>
#       <td id="T_5275e_row0_col3" class="data row0 col3" >-7.47%</td>
#       <td id="T_5275e_row0_col4" class="data row0 col4" >-6.57%</td>
#       <td id="T_5275e_row0_col5" class="data row0 col5" >-3.17%</td>
#       <td id="T_5275e_row0_col6" class="data row0 col6" >-7.06%</td>
#       <td id="T_5275e_row0_col7" class="data row0 col7" >-7.40%</td>
#       <td id="T_5275e_row0_col8" class="data row0 col8" >-7.57%</td>
#       <td id="T_5275e_row0_col9" class="data row0 col9" >-8.01%</td>
#     </tr>
#     <tr>
#       <th id="T_
#       <td id="T_5275e_row4_col9" class="data row4 col9" >17.83%</td>
#     </tr>
#     <tr>
#       <th id="T_5275e_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_5275e_row5_col0" class="data row5 col0" >30.96%</td>
#       <td id="T_5275e_row5_col1" class="data row5 col1" >28.26%</td>
#       <td id="T_5275e_row5_col2" class="data row5 col2" >29.80%</td>
#       <td id="T_5275e_row5_col3" class="data row5 col3" >26.95%</td>
#       <td id="T_5275e_row5_col4" class="data row5 col4" >22.92%</td>
#       <td id="T_5275e_row5_col5" class="data row5 col5" >26.33%</td>
#       <td id="T_5275e_row5_col6" class="data row5 col6" >25.65%</td

# %% [markdown]
# ### Monthly returns
#
# > Note: the flags `withcomp=True` includes the portfolios components while the flag `componly=True` excludes the aggregated portfolio.

# %%
ps.port_monthly_returns(withcomp=True, componly=True, fancy=True)
# Out:
# <style type="text/css">
# #T_071df_row0_col0, #T_071df_row0_col1, #T_071df_row0_col2, #T_071df_row0_col3, #T_071df_row0_col4, #T_071df_row0_col5, #T_071df_row0_col6, #T_071df_row0_col7, #T_071df_row0_col8, #T_071df_row0_col9, #T_071df_row2_col0, #T_071df_row2_col1, #T_071df_row2_col2, #T_071df_row2_col3, #T_071df_row2_col4, #T_071df_row2_col5, #T_071df_row2_col6, #T_071df_row2_col7, #T_071df_row2_col8, #T_071df_row2_col9, #T_071df_row3_col0, #T_071df_row3_col1, #T_071df_row3_col2, #T_071df_row3_col3, #T_071df_row3_col4, #T_071df_row3_col5, #T_071df_row3_col6, #T_071df_row3_col7, #T_071df_row3_col8, #T_071df_row3_col9, #T_071df_row5_col0, #T_071df_row5_col5, #T_071df_row5_col7, #T_071df_row7_col0, #T_071df_row7_col1, #T_071df_row7_col2, #T_071df_row7_col3, #T_071df_row7_col4, #T_071df_row7_col5, #T_071df_row7_col6, #T_071df_row7_col7, #T_071df_row7_col8, #T_071df_row7_col9, #T_071df_row8_col6, #T_071df_row10_col0, #T_071df_row10_col1, #T_071df_row10_col2, #T_071df_row10_col3, #T_071df_row10_col4, #T_071df_row10_col6, #T_071df_row10_col7, #T_071df_row10_col8, #T_071df_row10_col9, #T_071df_row14_col0, #T_071df_row14_col1, #T_071df_row14_col3, #T_071df_row14_col4, #T_071df_row14_col5, #T_071df_row14_col6, #T_071df_row14_col7, #T_071df_row14_col8, #T_071df_row14_col9, #T_071df_row15_col3, #T_071df_row15_col4, #T_071df_row15_col6, #T_071df_row15_col8, #T_071df_row15_col9, #T_071df_row16_col0, #T_071df_row16_col1, #T_071df_row16_col2, #T_071df_row16_col3, #T_071df_row16_col4, #T_071df_row16_col5, #T_071df_row16_col6, #T_071df_row16_col7, #T_071df_row16_col8, #T_071df_row16_col9, #T_071df_row17_col0, #T_071df_row17_col1, #T_071df_row17_col2, #T_071df_row17_col3, #T_071df_row17_col4, #T_071df_row17_col5, #T_071df_row17_col6, #T_071df_row17_col7, #T_071df_row
returns(fancy=True)
# Out:
# <style type="text/css">
# #T_d6d9a_row0_col0, #T_d6d9a_row0_col2, #T_d6d9a_row0_col3, #T_d6d9a_row0_col4, #T_d6d9a_row0_col5, #T_d6d9a_row0_col9, #T_d6d9a_row1_col0, #T_d6d9a_row1_col2, #T_d6d9a_row1_col4, #T_d6d9a_row1_col5, #T_d6d9a_row1_col9, #T_d6d9a_row2_col0, #T_d6d9a_row2_col1, #T_d6d9a_row2_col2, #T_d6d9a_row2_col5, #T_d6d9a_row2_col7, #T_d6d9a_row2_col8, #T_d6d9a_row2_col9, #T_d6d9a_row3_col0, #T_d6d9a_row3_col2, #T_d6d9a_row3_col5, #T_d6d9a_row3_col6, #T_d6d9a_row3_col8, #T_d6d9a_row3_col9, #T_d6d9a_row4_col0, #T_d6d9a_row4_col1, #T_d6d9a_row4_col2, #T_d6d9a_row4_col3, #T_d6d9a_row4_col4, #T_d6d9a_row4_col5, #T_d6d9a_row4_col6, #T_d6d9a_row4_col9, #T_d6d9a_row5_col1, #T_d6d9a_row5_col4, #T_d6d9a_row5_col6, #T_d6d9a_row5_col8, #T_d6d9a_row5_col9, #T_d6d9a_row6_col0, #T_d6d9a_row6_col1, #T_d6d9a_row6_col2, #T_d6d9a_row6_col3, #T_d6d9a_row6_col5, #T_d6d9a_row6_col6, #T_d6d9a_row6_col7, #T_d6d9a_row6_col8, #T_d6d9a_row6_col9, #T_d6d9a_row7_col2, #T_d6d9a_row7_col3, #T_d6d9a_row7_col4, #T_d6d9a_row7_col5, #T_d6d9a_row7_col6, #T_d6d9a_row7_col9, #T_d6d9a_row8_col2, #T_d6d9a_row8_col9, #T_d6d9a_row9_col0, #T_d6d9a_row9_col2, #T_d6d9a_row9_col4, #T_d6d9a_row9_col6, #T_d6d9a_row9_col7, #T_d6d9a_row9_col8, #T_d6d9a_row9_col9, #T_d6d9a_row10_col0, #T_d6d9a_row10_col2, #T_d6d9a_row10_col5, #T_d6d9a_row10_col7, #T_d6d9a_row10_col8, #T_d6d9a_row10_col9, #T_d6d9a_row11_col0, #T_d6d9a_row11_col4, #T_d6d9a_row11_col5, #T_d6d9a_row11_col6, #T_d6d9a_row11_col8, #T_d6d9a_row11_col9 {
#   color: black;
# }
# #T_d6d9a_row0_col1, #T_d6d9a_row0_col6, #T_d6d9a_row0_col7, #T_d6d9a_row0_col8, #T_d6d9a_row1_col1, #T_d6d9a_row1_col3, #T_d6d9a_row1_col6, #T_d6d9a_row1_col7, #T_d6d9a_row1_col8, #T_d6d9a_row2_col3, #T_d6d9a_row2_col4, #T_d6d9a_row2_col6, #T_d6d9a_row3_col1, #T_d6d9a_row3_col3, #T_d6d9a_row3_col4, #T_d6d9a_row3_col7, #T_d6d9a_row4_col7, #T_d6d9a_row4_col8, #T_d6d9a_row5_col0, #T_d6d9a_row5_col2, #T_d6d9a_row5_col3, #T_d6d9a_row5_col5, #T_d6d9a_row5_col7, #T_d6d9a_row6_col4, #T_d6d9a_row7_col0, #T_d6d9a_row7_col1, #T_d6d9a_row7_col7, #T_d6d9a_row7_col8, #T_d6d9a_row8_col0, #T_d6d9a_row8_col1, #T_d6d9a_row8_col3, #T_d6d9a_row8_col4, #T_d6d9a_row8_col5, #T_d6d9a_row8_col6, #T_d6d9a_row8_col7, #T_d6d9a_row8_col8, #T_d6d9a_row9_col1, #T_d6d9a_row9_col3, #T_d6d9a_row9_col5, #T_d6d9a_row10_col1, #T_d6d9a_row10_col3, #T_d6d9a_row10_col4, #T_d6d9a_row10_col6, #T_d6d9a_row11_col1, #T_d6d9a_row11_col2, #T_d6d9a_row11_col3, #T_d6d9a_row11_col7 {
#   color: red;
# }
# </style>
# <table id="T_d6d9a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_d6d9a_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_d6d9a_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_d6d9a_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_d6d9a_level0_col3" class="col_heading level0 col3" >2018</th>
#       <th id="T_d6d9a_level0_col4" class="col_heading level0 col4" >2019</th>
#       <th id="T_d6d9a_level0_col5" class="col_heading level0 col5" >2020</th>
#       <th id="T_d6d9a_level0_col6" class="col_heading level0 col6" >2021</th>
#       <th id="T_d6d9a_level0_col7" class="col_heading level0 col7" >2022</th>
#       <th id="T_d6d9a_level0_col8" class="col_heading level0 col8" >2023</th>
#       <th id="T_d6d9a_level0_col9" class="col_heading level0 col9" >2024</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6d9a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d6d9a_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_d6d9a_row0_col1" class="data row0 col1" >-3.94%</td>
#       <td id="T_d6d9a_row0_col2" class="data row0 col2" >4.72%</td>
#       <td id="T_d6d9a_row0_col3" class="data row0 col3" >7.19%</td>
#       <td id="T_d6d9a_row0_col4" class="data row0 col4" >5.10%</td>
#       <td id="T_d6d9a_row0_col5" class="data row0 col5" >4.28%</td>
#       <td id="T_d6d9a_row0_col6" class="data row0 col6" >-1.92%</td>
#       <td id="T_d6d9a_row0_col7" class="data row0 col7" >-7.47%</td>
#       <td id="T_d6d9a_row0_col8" class="data row0 col8" >-1.83%</td>
#       <td id="T_d6d9a_row0_col9" class="data row0 col9" >0.36%</td>
#     </tr>
#     <tr>
#       <th id="T_d6d9a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d6d9a_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_d6d9a_row1_col1" class="data row1 col1" >-0.04%</td>
#       <td id="T_d6d9a_row1_col2" class="data row1 col2" >4.28%</td>
#       <td id="T_d6d9a_row1_col3" class="data row1 col3" >-1.54%</td>
#       <td id="T_d6d9a_row1_col4" class="data row1 col4" >2.01%</td>
#       <td id="T_d6d9a_row1_col5" class="data row1 col5" >1.02%</td>
#       <td id="T_d6d9a_row1_col6" class="data row1 col6" >-2.93%</td>
#       <td id="T_d6d9a_row1_col7" class="data row1 col7" >-3.06%</td>
#       <td id="T_d6d9a_row1_col8" class="data row1 col8" >-4.64%</td>
#       <td id="T_d6d9a_row1_col9" class="data row1 col9" >2.74%</td>
#     </tr>
#     <tr>
#       <th id="T_d6d9a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d6d9a_row2_col0" class="data row2 col0" >nan%</td>
#       <td id="T_d6d9a_row2_col1" class="data row2 col1" >5.04%</td>
#       <td id="T_d6d9a_row2_col2" class="data row2 col2" >1.64%</td>
#       <td id="T_d6d9a_row2_col3" class="data row2 col3" >-0.26%</td>
#       <td id="T_d6d9a_row2_col4" class="data row2 col4" >-1.98%</td>
#       <td id="T_d6d9a_row2_col5" class="data row2 col5" >4.34%</td>
#       <td id="T_d6d9a_row2_col6" class="data row2 col6" >-1.52%</td>
#       <td id="T_d6d9a_row2_col7" class="data row2 col7" >5.51%</td>
#       <td id="T_d6d9a_row2_col8" class="data row2 col8" >1.65%</td>
#       <td id="T_d6d9a_row2_col9" class="data row2 col9" >3.88%</td>
#     </tr>
#     <tr>
#       <th id="T_d6d9a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d6d9a_row3_col0" class="data row3 col0" >nan%</td>
#       <td id="T_d6d9a_row3_col1" class="data row3 col1" >-0.94%</td>
#       <td id="T_d6d9a_row3_col2" class="data row3 col2" >2.34%</td>
#       <td id="T_d6d9a_row3_col3" class="data row3 col3" >-0.12%</td>
#       <td id="T_d6d9a_row3_col4" class="data row3 col4" >-1.57%</td>
#       <td id="T_d6d9a_row3_col5" class="data row3 col5" >6.44%</td>
#       <td id="T_d6d9a_row3_col6" class="data row3 col6" >3.60%</td>
#       <td id="T_d6d9a_row3_col7" class="data row3 col7" >-4.47%</td>
#       <td id="T_d6d9a_row3_col8" class="data row3 col8" >2.24%</td>
#       <td id="T_d6d9a_row3_col9" class="data row3 col9" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_d6d9a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d6d9a_row4_col0" class="data row4 col0" >nan%</td>
#       <td id="T_d6d9a_row4_col1" class="data row4 col1" >0.60%</td>
#       <td id="T_d6d9a_row4_col2" class="data row4 col2" >4.41%</td>
#       <td id="T_d6d9a_row4_col3" class="data row4 col3" >3.11%</td>
#       <td id="T_d6d9a_row4_col4" class="data row4 col4" >1.06%</td>
#       <td id="T_d6d9a_row4_col5" class="data row4 col5" >1.58%</td>
#       <td id="T_d6d9a_row4_col6" class="data row4 col6" >0.12%</td>
#       <td id="T_d6d9a_row4_col7" class="data row4 col7" >-0.57%</td>
#       <td id="T_d6d9a_row4_col8" class="data row4 col8" >-3.12%</td>
#       <td id="T_d6d9a_row4_col9" class="data row4 col9" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_d6d9a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d6d9a_row5_col0" class="data row5 col0" >-1.90%</td>
#       <td id="T_d6d9a_row5_col1" class="data row5 col1" >9.97%</td>
#       <td id="T_d6d9a_ro

# %% [markdown]
# ### P_Omega performance
#
# An example of individual portfolio performance inquiry.

# %%
pp['P_Omega'].port_perf(fancy=True)
# Out:
#             RR     DD     RoMaD     DD_date    DD_start      DD_end  DD_days
# symbol
# P_Omega   8.48 -22.85  0.371106  2018-12-24  2018-10-03  2019-08-28      329
# VGT      20.22 -35.07  0.576595  2022-10-14  2021-12-27  2023-11-20      693
# XLV      14.36 -28.40  0.505501  2020-03-23  2020-01-22  2020-07-15      175
# VHT      14.28 -28.85  0.494752  2020-03-23  2020-02-19  2020-06-08      110
# GLD       2.29 -42.11  0.054485  2015-12-17  2012-10-04  2020-07-22     2848
# TLT       0.56 -48.35  0.011678  2023-10-19  2020-08-04         NaN     1332

# %% [markdown]
# ### P_Omega drawdowns

# %%
pp['P_Omega'].port_drawdown(fancy=True)
# Out:
#        DD        Date       Start         End  NrDays
# No
# 1  -22.85  2018-12-24  2018-10-03  2019-08-28     329
# 2  -19.75  2015-09-28  2015-07-20  2016-06-28     344
# 3  -19.66  2023-10-03  2021-12-29         NaN     820
