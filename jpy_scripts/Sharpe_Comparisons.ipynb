# %% [markdown]
# # Sharpe optimal portfolio - comparisons
#
# This example compares the performance of several risk-Sharpe optimal portfolios.
#
# The CVaR, SMCR, MAD, LSSD, BTAD, BTSD, GINI, SD and MV risk-based portfolios are considered. We use the `rtype=Sharpe` optimization flag with a risk-free rate of 0 (default value).
#
# We start by importing **azapy** and other useful packages.

# %%
import sys
sys.path.append("..")
import azapy as az

print(f"azapy version {az.__version__}")
# Out:
# '0.1.1'

# %% [markdown]
# ### Collect historical market data
#
# - `symb` is the list of stock symbols (portfolio components).
# - `sdate` and `edate` are the start and end dates of historical time-series.
# - `force=True` get historical market data directly from the provider (in this case yahoo)
# - `save=False` the historical market data is not saved
#
# >For more information see https://azapy.readthedocs.io/en/latest/.

# %%
symb = ['GLD', 'TLT', 'XLV', 'VGT', 'PSJ']

sdate = "2012-01-01"
edate = "today"

mktdata = az.readMkT(symb, sdate=sdate, edate=edate, force=True, save=False)
# Out:
# get GLD from yahoo only
# get TLT from yahoo only
# get XLV from yahoo only
# get VGT from yahoo only
# get PSJ from yahoo only
#
# Request between 2012-01-01 : 2022-06-15
#                     GLD         TLT         XLV         VGT         PSJ
# source            yahoo       yahoo       yahoo       yahoo       yahoo
# force              True        True        True        True        True
# save              False       False       False       False       False
# file_dir         outDir      outDir      outDir      outDir      outDir
# file_format         csv         csv         csv         csv         csv
# api_key            None        None        None        None        None
# verbose            True        True        True        True        True
# error                No          No          No          No          No
# nrow               2631        2631        2631        2631        2631
# sdate        2012-01-03  2012-01-03  2012-01-03  2012-01-03  2012-01-03
# edate        2022-06-15  2022-06-15  2022-06-15  2022-06-15  2022-06-15
# extraction time 2.021 s

# %% [markdown]
# ### Set scenarios model parameters
#
# Since we plan to run many scenarios, it is useful to organize their model parameters in a dictionary.
# The keys are the portfolio names, and the values are the model parameters organized also as dictionaries:
# - 'type' : is the portfolio class used in the simulation,
# - 'm_param' : is a dictionary with parameters for `set_model` functions.
#
# Note that:
# - `'P_N'` is the reference equal weighted portfolio,
# - `'P_CVaR'` is the mCVaR optimal portfolio with confidence levels `alpha_CVaR` equal weighted,
# - `'P_SMCR'` is the mSMCR optimal portfolio with confidence levels `alpha_SMCR` equal weighted,
# - `'P_MAD'` is the mMAD optimal portfolio with weights `coef_MAD`,
# - `'P_LSSD'` is the mLSSD optimal portfolio with weights `coef_LSSD`,
# - `'P_Omega'` is the mBTAD optimal portfolio with threshold levels `alpha_BTAD` equal weighted,
# - `'P_Sortino'` is the mBTSD optimal portfolio with threshold levels `alpha_BTSD` equal weighted,
# - `'P_GINI'` is the Gini optimal portfolio,
# - `'P_MV'` is the MV optimal portfolio,
# - `'P_SD'` is the SD optimal portfolio.
#
#
# - In all cases the optimization type is set to `rtype='Sharpe'` (optimal portfolio with the same risk profile as the equal weighted portfolio) with risk-free rate mu0=0.
# - The `'hlength'` parameter (the length of historical data used in weights calibration) is set to 3.25 years except for `'P_GINI'` where it is set to 1.25 years (for computational speed convenience).
#
# > Note:
# > - mBTAD-Sharpe ratio is called Omega ratio
# > - mBTSD-Sharpe ratio is called Sortino ratio
# > - MV-Sharpe ratio is different than (SD) Sharp ratio

# %%
alpha_CVaR = [0.95, 0.90, 0.85]
alpha_SMCR = [0.9, 0.80]
rtype = 'Sharpe'
coef_MAD = [1./3.] * 3
coef_LSSD = [1./3.] * 3
alpha_BTAD = [-0.01, 0]
alpha_BTSD = [-0.01, 0]

models = {'P_CVaR-Sharpe': {'type': 'Port_CVaR', 'm_param': {'alpha': alpha_CVaR, 'rtype': rtype, 'hlength': 3.25}},
          'P_SMCR-Sharpe': {'type': 'Port_SMCR', 'm_param': {'alpha': alpha_SMCR, 'rtype': rtype, 'hlength': 3.25}},
          'P_MAD-Sharpe': {'type': 'Port_MAD', 'm_param': {'coef': coef_MAD, 'rtype': rtype, 'hlength': 3.25}},
          'P_LSSD-Sharpe': {'type': 'Port_LSSD', 'm_param': {'coef': coef_LSSD, 'rtype': rtype, 'hlength': 3.25}},
          'P_Omega': {'type': 'Port_BTAD', 'm_param': {'alpha': alpha_BTAD, 'rtype': rtype, 'hlength': 3.25}},
          'P_Sortino': {'type': 'Port_BTSD', 'm_param': {'alpha': alpha_BTSD, 'rtype': rtype, 'hlength': 3.25}},
          'P_GINI-Sharpe': {'type': 'Port_GINI', 'm_param': {'rtype': rtype, 'hlength': 1.25}},
          'P_MV-Sharpe': {'type': 'Port_MV', 'm_param': {'rtype': rtype, 'hlength': 3.25}},
          'P_Sharpe': {'type': 'Port_SD', 'm_param': {'rtype': rtype, 'hlength': 3.25}},
          'P_N': {'type': 'Port_ConstW', 'm_param': {'ww': None}}}

# %% [markdown]
# ### Main computation loop
#
# - `port` is a list containing the simulated time-series. We will use it to setup a simple portfolio *(see the documentation for `Port_Simple` class)*. It is a very convenient way to facilitate the visual and numerical comparisons between these portfolio performances.
# - `pp` is a dictionary holding the portfolio objects. They may be used later for further analytical inquires.

# %%
port = []
pp = {}
for key, val in models.items():
    ppz = getattr(az, val['type'])
    pp_ = ppz(mktdata, pname=key)
    pp[key] = pp_
    port_ = pp_.set_model(**val['m_param'])
    port.append(port_)

# %% [markdown]
# ### Prepare the results for comparisons
#
# Build a `Port_Simple` class holding all the computed portfolios as components. We use this structure to build comparative graphical and numerical performance reports. The aggregated portfolio of portfolios time-series will be neglected.
#
# >Note the call to `set_model` method that is a must.
#
# >Observation: `Port_Simple` is the class that supports the back testing of "Buy and Hold" portfolio (_see its documentation_).
# It also can be used as a tool to compare the performance of multiple portfolios. Here we use it in this latter capacity.

# %%
ps = az.Port_Simple(port, col='close', pname='ALL')
_ = ps.set_model()

# %% [markdown]
# ### Time-series visualization
#
# We used the flag `componly=True` to plot only the portfolio components.

# %%
_ = ps.port_view_all(componly=True, fancy=True)
# Out:
# <div>                            <div id="ae12bf21-dbef-441a-8eee-e47ecfa2ceac" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae12bf21-dbef-441a-8eee-e47ecfa2ceac")) {                    Plotly.newPlot(                        "ae12bf21-dbef-441a-8eee-e47ecfa2ceac",                        [{"line":{"width":1.5},"name":"P_CVaR-Sharpe","type":"scatter","x":["2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-22T00:00:00","2015-07-23T00:00:00","2015-07-24T00:00:00","2015-07-27T00:00:00","2015-07-28T00:00:00","2015-07-29T00:00:00","2015-07-30T00:00:00","2015-07-31T00:00:00","2015-08-03T00:00:00","2015-08-04T00:00:00","2015-08-05T00:00:00","2015-08-06T00:00:00","2015-08-07T00:00:00","2015-08-10T00:00:00","2015-08-11T00:00:00","2015-08-12T00:00:00","2015-08-13T00:00:00","2015-08-14T00:00:00","2015-08-17T00:00:00","2015-08-18T00:00:00","2015-08-19T00:00:00","2015-08-20T00:00:00","2015-08-21T00:00:00","2015-08-24T00:00:00","2015-08-25T00:00:00","2015-08-26T00:00:00","2015-08-27T00:00:00","2015-08-28T00:00:00","2015-08-31T00:00:00","2015-09-01T00:00:00","2015-09-02T00:00:00","2015-09-03T00:00:00","2015-09-04T00:00:00","2015-09-08T00:00:00","2015-09-09T00:00:00","2015-09-10T00:00:00","2015-09-11T00:00:00","2015-09-14T00:00:00","2015-09-15T00:00:00","2015-09-16T00:00:00","2015-09-17T00:00:00","2015-09-18T00:00:00","2015-09-21T00:00:00","2015-09-22T00:00:00","2015-09-23T00:00:00","2015-09-24T00:00:00","2015-09-25T00:00:00","2015-09-28T00:00:00","2015-09-29T00:00:00","2015-09-30T00:00:00","2015-10-01T00:00:00","2015-10-02T00:00:00","2015-10-05T00:00:00","2015-10-06T00:00:00","2015-10-07T00:00:00","2015-10-08T00:00:00","2015-10-09T00:00:00","2015-10-12T00:00:00","2015-10-13T00:00:00","2015-10-14T00:00:00","2015-10-15T00:00:00","2015-10-16T00:00:00","2015-10-19T00:00:00","2015-10-20T00:00:00","2015-10-21T00:00:00","2015-10-22T00:00:00","2015-10-23T00:00:00","2015-10-26T00:00:00","2015-10-27T00:00:00","2015-10-28T00:00:00","2015-10-29T00:00:00","2015-10-30T00:00:00","2015-11-02T00:00:00","2015-11-03T00:00:00","2015-11-04T00:00:00","2015-11-05T00:00:00","2015-11-06T00:00:00","2015-11-09T00:00:00","2015-11-10T00:00:00","2015-11-11T00:00:00","2015-11-12T00:00:00","2015-11-13T00:00:00","2015-11-16T00:00:00","2015-11-17T00:00:00","2015-11-18T00:00:00","2015-11-19T00:00:00","2015-11-20T00:00:00","2015-11-23T00:00:00","2015-11-24T00:00:00","2015-11-25T00:00:00","2015-11-27T00:00:00","2015-11-30T00:00:00","2015-12-01T00:00:00","2015-12-02T00:00:00","2015-12-03T00:00:00","2015-12-04T00:00:00","2015-12-07T00:00:00","2015-12-08T00:00:00","2015-12-09T00:00:00","2015-12-10T00:00:00","2015-12-11T00:00:00","2015-12-14T00:00:00","2015-12-15T00:00:00","2015-12-16T00:00:00","2015-12-17T00:00:00","2015-12-18T00:00:00","2015-12-21T00:00:00","2015-12-22T00:00:00","2015-12-23T00:00:00","2015-12-24T00:00:00","2015-12-28T00:00:00","2015-12-29T00:00:00","2015-12-30T00:00:00","2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T0 ...

# %% [markdown]
# ### Portfolio performances

# %%
ps.port_perf(componly=True, fancy=True)
# Out:
#                  RR     DD      Beta     DD_date    DD_start      DD_end
# symbol
# P_N            9.35 -20.67  0.452437  2022-06-14  2021-11-09         NaN
# P_GINI-Sharpe  8.59 -22.02  0.390269  2018-12-24  2018-09-14  2019-12-26
# P_MV-Sharpe    7.17 -18.70  0.383431  2022-06-14  2021-12-30         NaN
# P_Omega        7.00 -18.39  0.380615  2020-03-20  2020-02-19  2020-07-15
# P_Sortino      6.68 -18.31  0.364640  2020-03-20  2020-02-19  2020-06-23
# P_CVaR-Sharpe  6.48 -17.80  0.363844  2020-03-20  2020-02-19  2020-06-22
# P_LSSD-Sharpe  6.51 -19.02  0.342497  2020-03-20  2020-02-19  2020-07-20
# P_SMCR-Sharpe  6.47 -18.99  0.340745  2020-03-20  2020-02-19  2020-07-17
# P_MAD-Sharpe   7.22 -22.60  0.319305  2020-03-20  2020-02-19  2020-07-27
# P_Sharpe       6.64 -22.52  0.294684  2022-06-14  2021-12-28         NaN

# %% [markdown]
# ### Annual returns
#
# Note the best and worst performer each year.
#
# > The flags `withcomp=True` includes the portfolios components while the flag `componly=True` excludes the aggregated portfolio of portfolios.

# %%
ps.port_annual_returns(withcomp=True, componly=True, fancy=True)
# Out:
# <style type="text/css">
# #T_b0fe7_row0_col0, #T_b0fe7_row0_col1, #T_b0fe7_row0_col2, #T_b0fe7_row0_col3, #T_b0fe7_row0_col4, #T_b0fe7_row0_col5, #T_b0fe7_row0_col6, #T_b0fe7_row0_col7, #T_b0fe7_row0_col8, #T_b0fe7_row0_col9, #T_b0fe7_row1_col1, #T_b0fe7_row3_col1, #T_b0fe7_row7_col0, #T_b0fe7_row7_col1, #T_b0fe7_row7_col2, #T_b0fe7_row7_col3, #T_b0fe7_row7_col4, #T_b0fe7_row7_col5, #T_b0fe7_row7_col6, #T_b0fe7_row7_col7, #T_b0fe7_row7_col8, #T_b0fe7_row7_col9 {
#   color: red;
# }
# #T_b0fe7_row1_col0, #T_b0fe7_row1_col2, #T_b0fe7_row1_col3, #T_b0fe7_row1_col4, #T_b0fe7_row1_col5, #T_b0fe7_row1_col6, #T_b0fe7_row1_col7, #T_b0fe7_row1_col8, #T_b0fe7_row1_col9, #T_b0fe7_row2_col0, #T_b0fe7_row2_col1, #T_b0fe7_row2_col2, #T_b0fe7_row2_col3, #T_b0fe7_row2_col4, #T_b0fe7_row2_col5, #T_b0fe7_row2_col6, #T_b0fe7_row2_col7, #T_b0fe7_row2_col8, #T_b0fe7_row2_col9, #T_b0fe7_row3_col0, #T_b0fe7_row3_col2, #T_b0fe7_row3_col3, #T_b0fe7_row3_col4, #T_b0fe7_row3_col5, #T_b0fe7_row3_col6, #T_b0fe7_row3_col7, #T_b0fe7_row3_col8, #T_b0fe7_row3_col9, #T_b0fe7_row4_col0, #T_b0fe7_row4_col1, #T_b0fe7_row4_col2, #T_b0fe7_row4_col3, #T_b0fe7_row4_col4, #T_b0fe7_row4_col5, #T_b0fe7_row4_col6, #T_b0fe7_row4_col7, #T_b0fe7_row4_col8, #T_b0fe7_row4_col9, #T_b0fe7_row5_col0, #T_b0fe7_row5_col1, #T_b0fe7_row5_col2, #T_b0fe7_row5_col3, #T_b0fe7_row5_col4, #T_b0fe7_row5_col5, #T_b0fe7_row5_col6, #T_b0fe7_row5_col7, #T_b0fe7_row5_col8, #T_b0fe7_row5_col9, #T_b0fe7_row6_col0, #T_b0fe7_row6_col1, #T_b0fe7_row6_col2, #T_b0fe7_row6_col3, #T_b0fe7_row6_col4, #T_b0fe7_row6_col5, #T_b0fe7_row6_col6, #T_b0fe7_row6_col7, #T_b0fe7_row6_col8, #T_b0fe7_row6_col9 {
#   color: black;
# }
# </style>
# <table id="T_b0fe7_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="col_heading level0 col0" >P_CVaR-Sharpe</th>
#       <th class="col_heading level0 col1" >P_GINI-Sharpe</th>
#       <th class="col_heading level0 col2" >P_LSSD-Sharpe</th>
#       <th class="col_heading level0 col3" >P_MAD-Sharpe</th>
#       <th class="col_heading level0 col4" >P_MV-Sharpe</th>
#       <th class="col_heading level0 col5" >P_N</th>
#       <th class="col_heading level0 col6" >P_Omega</th>
#       <th class="col_heading level0 col7" >P_SMCR-Sharpe</th>
#       <th class="col_heading level0 col8" >P_Sharpe</th>
#       <th class="col_heading level0 col9" >P_Sortino</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0fe7_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_b0fe7_row0_col0" class="data row0 col0" >-2.59%</td>
#       <td id="T_b0fe7_row0_col1" class="data row0 col1" >-3.28%</td>
#       <td id="T_b0fe7_row0_col2" class="data row0 col2" >-2.66%</td>
#       <td id="T_b0fe7_row0_col3" class="data row0 col3" >-1.38%</td>
#       <td id="T_b0fe7_row0_col4" class="data row0 col4" >-1.38%</td>
#       <td id="T_b0fe7_row0_col5" class="data row0 col5" >-1.59%</td>
#       <td id="T_b0fe7_row0_col6" class="data row0 col6" >-3.89%</td>
#       <td id="T_b0fe7_row0_col7" class="data row0 col7" >-4.70%</td>
#       <td id="T_b0fe7_row0_col8" class="data row0 col8" >-1.71%</td>
#       <td id="T_b0fe7_row0_col9" class="data row0 col9" >-4.56%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_b0fe7_row1_col0" class="data row1 col0" >1.31%</td>
#       <td id="T_b0fe7_row1_col1" class="data row1 col1" >-1.80%</td>
#       <td id="T_b0fe7_row1_col2" class="data row1 col2" >1.32%</td>
#       <td id="T_b0fe7_row1_col3" class="data row1 col3" >0.66%</td>
#       <td id="T_b0fe7_row1_col4" class="data row1 col4" >2.92%</td>
#       <td id="T_b0fe7_row1_col5" class="data row1 col5" >8.21%</td>
#       <td id="T_b0fe7_row1_col6" class="data row1 col6" >1.06%</td>
#       <td id="T_b0fe7_row1_col7" class="data row1 col7" >1.49%</td>
#       <td id="T_b0fe7_row1_col8" class="data row1 col8" >1.91%</td>
#       <td id="T_b0fe7_row1_col9" class="data row1 col9" >1.34%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_b0fe7_row2_col0" class="data row2 col0" >25.79%</td>
#       <td id="T_b0fe7_row2_col1" class="data row2 col1" >37.17%</td>
#       <td id="T_b0fe7_row2_col2" class="data row2 col2" >25.84%</td>
#       <td id="T_b0fe7_row2_col3" class="data row2 col3" >28.05%</td>
#       <td id="T_b0fe7_row2_col4" class="data row2 col4" >25.63%</td>
#       <td id="T_b0fe7_row2_col5" class="data row2 col5" >23.12%</td>
#       <td id="T_b0fe7_row2_col6" class="data row2 col6" >27.54%</td>
#       <td id="T_b0fe7_row2_col7" class="data row2 col7" >25.14%</td>
#       <td id="T_b0fe7_row2_col8" class="data row2 col8" >26.65%</td>
#       <td id="T_b0fe7_row2_col9" class="data row2 col9" >26.01%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_b0fe7_row3_col0" class="data row3 col0" >0.35%</td>
#       <td id="T_b0fe7_row3_col1" class="data row3 col1" >-2.94%</td>
#       <td id="T_b0fe7_row3_col2" class="data row3 col2" >0.46%</td>
#       <td id="T_b0fe7_row3_col3" class="data row3 col3" >2.37%</td>
#       <td id="T_b0fe7_row3_col4" class="data row3 col4" >1.17%</td>
#       <td id="T_b0fe7_row3_col5" class="data row3 col5" >2.52%</td>
#       <td id="T_b0fe7_row3_col6" class="data row3 col6" >1.01%</td>
#       <td id="T_b0fe7_row3_col7" class="data row3 col7" >0.08%</td>
#       <td id="T_b0fe7_row3_col8" class="data row3 col8" >3.05%</td>
#       <td id="T_b0fe7_row3_col9" class="data row3 col9" >0.59%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_b0fe7_row4_col0" class="data row4 col0" >24.56%</td>
#       <td id="T_b0fe7_row4_col1" class="data row4 col1" >22.37%</td>
#       <td id="T_b0fe7_row4_col2" class="data row4 col2" >25.09%</td>
#       <td id="T_b0fe7_row4_col3" class="data row4 col3" >29.20%</td>
#       <td id="T_b0fe7_row4_col4" class="data row4 col4" >26.39%</td>
#       <td id="T_b0fe7_row4_col5" class="data row4 col5" >25.77%</td>
#       <td id="T_b0fe7_row4_col6" class="data row4 col6" >27.69%</td>
#       <td id="T_b0fe7_row4_col7" class="data row4 col7" >26.28%</td>
#       <td id="T_b0fe7_row4_col8" class="data row4 col8" >27.87%</td>
#       <td id="T_b0fe7_row4_col9" class="data row4 col9" >26.27%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_b0fe7_row5_col0" class="data row5 col0" >12.98%</td>
#       <td id="T_b0fe7_row5_col1" class="data row5 col1" >21.47%</td>
#       <td id="T_b0fe7_row5_col2" class="data row5 col2" >11.84%</td>
#       <td id="T_b0fe7_row5_col3" class="data row5 col3" >11.65%</td>
#       <td id="T_b0fe7_row5_col4" class="data row5 col4" >10.40%</td>
#       <td id="T_b0fe7_row5_col5" class="data row5 col5" >25.54%</td>
#       <td id="T_b0fe7_row5_col6" class="data row5 col6" >11.48%</td>
#       <td id="T_b0fe7_row5_col7" class="data row5 col7" >13.06%</td>
#       <td id="T_b0fe7_row5_col8" class="data row5 col8" >8.97%</td>
#       <td id="T_b0fe7_row5_col9" class="data row5 col9" >12.83%</td>
#     </tr>
#     <tr>
#       <th id="T_b0fe7_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_b0fe7_row6_col0" class="data row6 col0" >3.29%</td>
#       <td id="T_b0fe7_row6_col1" class="data row6 col1" >12.55%</td>
#       <td id="T_b0fe7_row6_col2" class="data row6 col2" >4.92%</td>
#       <td id="T_b0fe7_row6_col3" class="data row6 col3" >7.87%</td>
#       <td id="T_b0fe7_row6_col4" class="data row6 col4" >8.58%</td>

# %% [markdown]
# ### Monthly returns
#
# > Note: the flags `withcomp=True` includes the portfolios components while the flag `componly=True` excludes the aggregated portfolio.

# %%
ps.port_monthly_returns(withcomp=True, componly=True, fancy=True)
# Out:
# <style type="text/css">
# #T_f15db_row0_col0, #T_f15db_row0_col1, #T_f15db_row0_col2, #T_f15db_row0_col3, #T_f15db_row0_col4, #T_f15db_row0_col5, #T_f15db_row0_col6, #T_f15db_row0_col7, #T_f15db_row0_col8, #T_f15db_row0_col9, #T_f15db_row2_col0, #T_f15db_row2_col1, #T_f15db_row2_col2, #T_f15db_row2_col3, #T_f15db_row2_col4, #T_f15db_row2_col5, #T_f15db_row2_col6, #T_f15db_row2_col7, #T_f15db_row2_col8, #T_f15db_row2_col9, #T_f15db_row3_col0, #T_f15db_row3_col1, #T_f15db_row3_col2, #T_f15db_row3_col3, #T_f15db_row3_col4, #T_f15db_row3_col5, #T_f15db_row3_col6, #T_f15db_row3_col7, #T_f15db_row3_col8, #T_f15db_row3_col9, #T_f15db_row5_col0, #T_f15db_row5_col1, #T_f15db_row5_col2, #T_f15db_row5_col3, #T_f15db_row5_col4, #T_f15db_row5_col5, #T_f15db_row5_col6, #T_f15db_row5_col7, #T_f15db_row5_col8, #T_f15db_row5_col9, #T_f15db_row6_col5, #T_f15db_row7_col0, #T_f15db_row7_col1, #T_f15db_row7_col2, #T_f15db_row7_col3, #T_f15db_row7_col4, #T_f15db_row7_col5, #T_f15db_row7_col6, #T_f15db_row7_col7, #T_f15db_row7_col8, #T_f15db_row7_col9, #T_f15db_row8_col3, #T_f15db_row8_col8, #T_f15db_row10_col0, #T_f15db_row10_col1, #T_f15db_row10_col2, #T_f15db_row10_col3, #T_f15db_row10_col4, #T_f15db_row10_col6, #T_f15db_row10_col7, #T_f15db_row10_col8, #T_f15db_row10_col9, #T_f15db_row14_col0, #T_f15db_row14_col2, #T_f15db_row14_col3, #T_f15db_row14_col4, #T_f15db_row14_col5, #T_f15db_row14_col6, #T_f15db_row14_col7, #T_f15db_row14_col8, #T_f15db_row14_col9, #T_f15db_row15_col1, #T_f15db_row15_col2, #T_f15db_row15_col7, #T_f15db_row16_col0, #T_f15db_row16_col1, #T_f15db_row16_col2, #T_f15db_row16_col3, #T_f15db_row16_col4, #T_f15db_row16_col5, #T_f15db_row16_col6, #T_f15db_row16_col7, #T_f15db_row16_col8, #T_f15db_row16_col9, #T_f15db_row17_col0, #T_f15db_row17_col1, #T_f15db_row17_col2, #T_f15db_row17_col3, #T_f15db_row17_col4, #T_f15db_row17_col5, #T_f15db_row17_col6, #T_f15db_row17_col7, #T_f15db_row17_col8, #T_f15db_row17_col9, #T_f15db_row21_col5, #T_f15db_row24_col0, #T_f15db_row24_col1, #T_f15db_row24_col2, #T_f15db_row24_col3, #T_f15db_row24_col4, #T_f15db_row24_col5, #T_f15db_row24_col6, #T_f15db_row24_col7, #T_f15db_row24_col8, #T_f15db_row24_col9, #T_f15db_row32_col0, #T_f15db_row32_col1, #T_f15db_row32_col2, #T_f15db_row32_col4, #T_f15db_row32_col5, #T_f15db_row32_col6, #T_f15db_row32_col7, #T_f15db_row32_col9, #T_f15db_row33_col1, #T_f15db_row33_col3, #T_f15db_row33_col4, #T_f15db_row33_col6, #T_f15db_row33_col8, #T_f15db_row36_col0, #T_f15db_row36_col1, #T_f15db_row36_col2, #T_f15db_row36_col3, #T_f15db_row36_col4, #T_f15db_row36_col5, #T_f15db_row36_col6, #T_f15db_row36_col7, #T_f15db_row36_col8, #T_f15db_row36_col9, #T_f15db_row39_col0, #T_f15db_row39_col1, #T_f15db_row39_col2, #T_f15db_row39_col3, #T_f15db_row39_col4, #T_f15db_row39_col6, #T_f15db_row39_col7, #T_f15db_row39_col8, #T_f15db_row39_col9, #T_f15db_row40_col0, #T_f15db_row40_col1, #T_f15db_row40_col2, #T_f15db_row40_col3, #T_f15db_row40_col4, #T_f15db_row40_col5, #T_f15db_row40_col6, #T_f15db_row40_col7, #T_f15db_row40_col8, #T_f15db_row40_col9, #T_f15db_row41_col0, #T_f15db_row41_col2, #T_f15db_row41_col3, #T_f15db_row41_col4, #T_f15db_row41_col6, #T_f15db_row41_col7, #T_f15db_row41_col8, #T_f15db_row41_col9, #T_f15db_row42_col0, #T_f15db_row42_col1, #T_f15db_row42_col2, #T_f15db_row42_col3, #T_f15db_row42_col4, #T_f15db_row42_col5, #T_f15db_row42_col6, #T_f15db_row42_col7, #T_f15db_row42_col8, #T_f15db_row42_col9, #T_f15db_row45_col0, #T_f15db_row45_col1, #T_f15db_row45_col2, #T_f15db_row45_col3, #T_f15db_row45_col4, #T_f15db_row45_col5, #T_f15db_row45_col6, #T_f15db_row45_col7, #T_f15db_row45_col8, #T_f15db_row45_col9, #T_f15db_row47_col0, #T_f15db_row47_col1, #T_f15db_row47_col2, #T_f15db_row47_col3, #T_f15db_row47_col4, #T_f15db_row47_col5, #T_f15db_row47_col6, #T_f15db_row47_col7, #T_f15db_row47_col8, #T_f15db_row47_col9, #T_f15db_row49_col1, #T_f15db_row50_col0, #T_f15db_row50_col2, #T_f15db_row50_col3, #T_f15db_row50_col4, #T_f15db_row50_col6, #T_f15db_row50_col7, #T_f15db_row50_col8,  ...
#   color: red;
# }
# #T_f15db_row1_col0, #T_f15db_row1_col1, #T_f15db_row1_col2, #T_f15db_row1_col3, #T_f15db_row1_col4, #T_f15db_row1_col5, #T_f15db_row1_col6, #T_f15db_row1_col7, #T_f15db_row1_col8, #T_f15db_row1_col9, #T_f15db_row4_col0, #T_f15db_row4_col1, #T_f15db_row4_col2, #T_f15db_row4_col3, #T_f15db_row4_col4, #T_f15db_row4_col5, #T_f15db_row4_col6, #T_f15db_row4_col7, #T_f15db_row4_col8, #T_f15db_row4_col9, #T_f15db_r

# %% [markdown]
# ### A closer look at P_Omega portfolio

# %%
pp['P_Omega'].port_monthly_returns(fancy=True)
# Out:
# <style type="text/css">
# #T_9cdd5_row0_col0, #T_9cdd5_row0_col2, #T_9cdd5_row0_col3, #T_9cdd5_row0_col4, #T_9cdd5_row0_col5, #T_9cdd5_row1_col0, #T_9cdd5_row1_col1, #T_9cdd5_row1_col2, #T_9cdd5_row1_col4, #T_9cdd5_row2_col0, #T_9cdd5_row2_col1, #T_9cdd5_row2_col2, #T_9cdd5_row2_col7, #T_9cdd5_row3_col0, #T_9cdd5_row3_col2, #T_9cdd5_row3_col3, #T_9cdd5_row3_col4, #T_9cdd5_row3_col5, #T_9cdd5_row3_col6, #T_9cdd5_row4_col0, #T_9cdd5_row4_col1, #T_9cdd5_row4_col2, #T_9cdd5_row4_col3, #T_9cdd5_row4_col5, #T_9cdd5_row4_col6, #T_9cdd5_row5_col1, #T_9cdd5_row5_col4, #T_9cdd5_row6_col0, #T_9cdd5_row6_col1, #T_9cdd5_row6_col2, #T_9cdd5_row6_col3, #T_9cdd5_row6_col4, #T_9cdd5_row6_col5, #T_9cdd5_row6_col6, #T_9cdd5_row6_col7, #T_9cdd5_row7_col2, #T_9cdd5_row7_col3, #T_9cdd5_row7_col6, #T_9cdd5_row7_col7, #T_9cdd5_row8_col1, #T_9cdd5_row8_col2, #T_9cdd5_row8_col7, #T_9cdd5_row9_col0, #T_9cdd5_row9_col2, #T_9cdd5_row9_col4, #T_9cdd5_row9_col6, #T_9cdd5_row9_col7, #T_9cdd5_row10_col2, #T_9cdd5_row10_col4, #T_9cdd5_row10_col5, #T_9cdd5_row10_col7, #T_9cdd5_row11_col0, #T_9cdd5_row11_col1, #T_9cdd5_row11_col2, #T_9cdd5_row11_col4, #T_9cdd5_row11_col5, #T_9cdd5_row11_col6, #T_9cdd5_row11_col7 {
#   color: black;
# }
# #T_9cdd5_row0_col1, #T_9cdd5_row0_col6, #T_9cdd5_row0_col7, #T_9cdd5_row1_col3, #T_9cdd5_row1_col5, #T_9cdd5_row1_col6, #T_9cdd5_row1_col7, #T_9cdd5_row2_col3, #T_9cdd5_row2_col4, #T_9cdd5_row2_col5, #T_9cdd5_row2_col6, #T_9cdd5_row3_col1, #T_9cdd5_row3_col7, #T_9cdd5_row4_col4, #T_9cdd5_row4_col7, #T_9cdd5_row5_col0, #T_9cdd5_row5_col2, #T_9cdd5_row5_col3, #T_9cdd5_row5_col5, #T_9cdd5_row5_col6, #T_9cdd5_row5_col7, #T_9cdd5_row7_col0, #T_9cdd5_row7_col1, #T_9cdd5_row7_col4, #T_9cdd5_row7_col5, #T_9cdd5_row8_col0, #T_9cdd5_row8_col3, #T_9cdd5_row8_col4, #T_9cdd5_row8_col5, #T_9cdd5_row8_col6, #T_9cdd5_row9_col1, #T_9cdd5_row9_col3, #T_9cdd5_row9_col5, #T_9cdd5_row10_col0, #T_9cdd5_row10_col1, #T_9cdd5_row10_col3, #T_9cdd5_row10_col6, #T_9cdd5_row11_col3 {
#   color: red;
# }
# </style>
# <table id="T_9cdd5_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="col_heading level0 col0" >2015</th>
#       <th class="col_heading level0 col1" >2016</th>
#       <th class="col_heading level0 col2" >2017</th>
#       <th class="col_heading level0 col3" >2018</th>
#       <th class="col_heading level0 col4" >2019</th>
#       <th class="col_heading level0 col5" >2020</th>
#       <th class="col_heading level0 col6" >2021</th>
#       <th class="col_heading level0 col7" >2022</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cdd5_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9cdd5_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_9cdd5_row0_col1" class="data row0 col1" >-2.08%</td>
#       <td id="T_9cdd5_row0_col2" class="data row0 col2" >2.36%</td>
#       <td id="T_9cdd5_row0_col3" class="data row0 col3" >4.03%</td>
#       <td id="T_9cdd5_row0_col4" class="data row0 col4" >6.41%</td>
#       <td id="T_9cdd5_row0_col5" class="data row0 col5" >1.62%</td>
#       <td id="T_9cdd5_row0_col6" class="data row0 col6" >-1.89%</td>
#       <td id="T_9cdd5_row0_col7" class="data row0 col7" >-4.35%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9cdd5_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_9cdd5_row1_col1" class="data row1 col1" >1.00%</td>
#       <td id="T_9cdd5_row1_col2" class="data row1 col2" >3.49%</td>
#       <td id="T_9cdd5_row1_col3" class="data row1 col3" >-0.06%</td>
#       <td id="T_9cdd5_row1_col4" class="data row1 col4" >4.60%</td>
#       <td id="T_9cdd5_row1_col5" class="data row1 col5" >-3.62%</td>
#       <td id="T_9cdd5_row1_col6" class="data row1 col6" >-3.91%</td>
#       <td id="T_9cdd5_row1_col7" class="data row1 col7" >-0.07%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9cdd5_row2_col0" class="data row2 col0" >nan%</td>
#       <td id="T_9cdd5_row2_col1" class="data row2 col1" >1.95%</td>
#       <td id="T_9cdd5_row2_col2" class="data row2 col2" >0.85%</td>
#       <td id="T_9cdd5_row2_col3" class="data row2 col3" >-0.05%</td>
#       <td id="T_9cdd5_row2_col4" class="data row2 col4" >-0.55%</td>
#       <td id="T_9cdd5_row2_col5" class="data row2 col5" >-6.39%</td>
#       <td id="T_9cdd5_row2_col6" class="data row2 col6" >-2.04%</td>
#       <td id="T_9cdd5_row2_col7" class="data row2 col7" >1.11%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9cdd5_row3_col0" class="data row3 col0" >nan%</td>
#       <td id="T_9cdd5_row3_col1" class="data row3 col1" >-0.99%</td>
#       <td id="T_9cdd5_row3_col2" class="data row3 col2" >1.96%</td>
#       <td id="T_9cdd5_row3_col3" class="data row3 col3" >1.30%</td>
#       <td id="T_9cdd5_row3_col4" class="data row3 col4" >3.46%</td>
#       <td id="T_9cdd5_row3_col5" class="data row3 col5" >8.89%</td>
#       <td id="T_9cdd5_row3_col6" class="data row3 col6" >2.33%</td>
#       <td id="T_9cdd5_row3_col7" class="data row3 col7" >-5.68%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9cdd5_row4_col0" class="data row4 col0" >nan%</td>
#       <td id="T_9cdd5_row4_col1" class="data row4 col1" >2.43%</td>
#       <td id="T_9cdd5_row4_col2" class="data row4 col2" >3.25%</td>
#       <td id="T_9cdd5_row4_col3" class="data row4 col3" >4.99%</td>
#       <td id="T_9cdd5_row4_col4" class="data row4 col4" >-4.15%</td>
#       <td id="T_9cdd5_row4_col5" class="data row4 col5" >3.31%</td>
#       <td id="T_9cdd5_row4_col6" class="data row4 col6" >2.62%</td>
#       <td id="T_9cdd5_row4_col7" class="data row4 col7" >-2.07%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9cdd5_row5_col0" class="data row5 col0" >-2.03%</td>
#       <td id="T_9cdd5_row5_col1" class="data row5 col1" >2.50%</td>
#       <td id="T_9cdd5_row5_col2" class="data row5 col2" >-2.07%</td>
#       <td id="T_9cdd5_row5_col3" class="data row5 col3" >-4.11%</td>
#       <td id="T_9cdd5_row5_col4" class="data row5 col4" >8.11%</td>
#       <td id="T_9cdd5_row5_col5" class="data row5 col5" >-0.91%</td>
#       <td id="T_9cdd5_row5_col6" class="data row5 col6" >-1.92%</td>
#       <td id="T_9cdd5_row5_col7" class="data row5 col7" >-3.79%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_9cdd5_row6_col0" class="data row6 col0" >2.16%</td>
#       <td id="T_9cdd5_row6_col1" class="data row6 col1" >3.75%</td>
#       <td id="T_9cdd5_row6_col2" class="data row6 col2" >3.35%</td>
#       <td id="T_9cdd5_row6_col3" class="data row6 col3" >0.57%</td>
#       <td id="T_9cdd5_row6_col4" class="data row6 col4" >3.78%</td>
#       <td id="T_9cdd5_row6_col5" class="data row6 col5" >7.33%</td>
#       <td id="T_9cdd5_row6_col6" class="data row6 col6" >2.55%</td>
#       <td id="T_9cdd5_row6_col7" class="data row6 col7" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_9cdd5_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_9cdd5_row7_col0" class="data row7 col0" >-7.43%</td>
#       <td id="T_9cdd5_row7_col1" class="data row7 col1" >-0.45%</td>
#       <td id="T_9cdd5_row7_col2" class="data row7 col2" >2.60%</td>
#       <td id="T_9cdd5_row7_col3" class="data row7 col3" >6.79%</td>
#       <td id="T_9cdd5_row7_col4" class="data row7 col4" >-2.84%</td>
#       <td id="T_9cdd5_row7_col5" class="data row7 col5" >-0.42%</td>
#       <td id="T_9cdd5_row7_col6" class="data row7 col6" >0.70%</td>

# %% [markdown]
# ### P_Omega performance
#
# An example of individual portfolio performance inquiry.

# %%
pp['P_Omega'].port_perf(fancy=True)
# Out:
#             RR     DD      Beta     DD_date    DD_start      DD_end
# symbol
# P_Omega   7.00 -18.39  0.380615  2020-03-20  2020-02-19  2020-07-15
# VGT      18.52 -31.84  0.581743  2020-03-23  2020-02-19  2020-06-09
# XLV      14.50 -28.40  0.510377  2020-03-23  2020-01-22  2020-07-15
# PSJ      14.59 -50.02  0.291617  2022-06-13  2021-02-12         NaN
# TLT       1.65 -34.76  0.047501  2022-06-14  2020-08-04         NaN
# GLD       0.88 -42.11  0.020782  2015-12-17  2012-10-04  2020-07-22

# %% [markdown]
# ### P_Omega drawdowns

# %%
pp['P_Omega'].port_drawdown(fancy=True)
# Out:
#        DD        Date       Start         End
# No
# 1  -18.39  2020-03-20  2020-02-19  2020-07-15
# 2  -16.76  2022-06-14  2021-11-17         NaN
# 3  -16.40  2018-12-24  2018-08-31  2019-03-13
# 4  -14.16  2015-09-28  2015-08-05  2016-07-01
# 5   -9.89  2021-03-08  2020-08-06  2021-07-29

# %% [markdown]
# ### P_Omega weights

# %%
pp['P_Omega'].get_weights(fancy=True)
# Out:
#         Droll       Dfix      Dhist    GLD    PSJ    TLT    VGT    XLV
# 0  2015-06-25 2015-06-24 2012-03-23   0.00   0.00   7.21   0.00  92.79
# 1  2015-09-25 2015-09-24 2012-06-22   0.00  12.32  22.49   0.00  65.19
# 2  2015-12-28 2015-12-24 2012-09-24   0.00  26.31  30.06  22.88  20.75
# 3  2016-03-28 2016-03-24 2012-12-24   0.00   0.00  38.21  23.82  37.97
# 4  2016-06-27 2016-06-24 2013-03-22   0.00   9.72  39.56  22.77  27.95
# 5  2016-09-27 2016-09-26 2013-06-26   0.00  28.11  50.41   1.33  20.15
# 6  2016-12-27 2016-12-23 2013-09-23   0.00   0.00  36.08  63.92   0.00
# 7  2017-03-28 2017-03-27 2013-12-27   0.00   0.00  32.62  67.38   0.00
# 8  2017-06-27 2017-06-26 2014-03-26   0.00   0.00  30.58  69.42   0.00
# 9  2017-09-26 2017-09-25 2014-06-25   0.00   4.15  29.86  65.99   0.00
# 10 2017-12-26 2017-12-22 2014-09-22   0.00  11.58  26.94  61.48   0.00
# 11 2018-03-26 2018-03-23 2014-12-23   0.00   1.18  24.27  74.55   0.00
# 12 2018-06-26 2018-06-25 2015-03-25   0.00  15.79  24.59  59.62   0.00
# 13 2018-09-25 2018-09-24 2015-06-24   4.77   0.00  23.83  71.40   0.00
# 14 2018-12-26 2018-12-24 2015-09-24  31.06   0.00   0.00  68.94   0.00
# 15 2019-03-26 2019-03-25 2015-12-24  11.91  61.86   0.00  20.41   5.82
# 16 2019-06-25 2019-06-24 2016-03-24   8.91  63.60   0.00  24.06   3.43
# 17 2019-09-25 2019-09-24 2016-06-24  17.26  47.82   0.00  34.92   0.00
# 18 2019-12-26 2019-12-24 2016-09-23  48.43  19.03   0.00  15.71  16.83
# 19 2020-03-26 2020-03-25 2016-12-23  41.10   7.80  24.61   6.90  19.60
# 20 2020-06-25 2020-06-24 2017-03-24  40.12   7.67  26.12   6.25  19.84
# 21 2020-09-25 2020-09-24 2017-06-23  41.77   6.91  24.14   8.35  18.83
# 22 2020-12-28 2020-12-24 2017-09-22  45.46  17.35  17.47   0.31  19.41
# 23 2021-03-26 2021-03-25 2017-12-22  48.53  24.04  11.32   0.00  16.12
# 24 2021-06-25 2021-06-24 2018-03-23  42.99   7.66  10.17   8.92  30.26
# 25 2021-09-27 2021-09-24 2018-06-22  57.42   1.16   2.42  21.51  17.49
# 26 2021-12-28 2021-12-27 2018-09-27  36.29   0.00  16.30  47.41   0.00
# 27 2022-03-28 2022-03-25 2018-12-24  57.23   0.00   0.00  40.50   2.27
# 28 2022-06-27 2022-06-24 2019-03-22    NaN    NaN    NaN    NaN    NaN
