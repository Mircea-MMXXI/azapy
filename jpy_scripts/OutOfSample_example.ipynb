# %% [markdown]
# # Out-of-sample analysis - am example
# ### Mixture of CVaR's with Sharpe type of optimization
#
# This is an illustration of *out-of-sample analysis* workflow. It is also known as *back testing* or *historical simulation*.
#
# The example presented here is for a mCVaR (a mixture of 3 CVaR's) with Sharpe type of optimization (*i.e.* the portfolio that maximizes the mCVaR-Sharpe ratio).
#
# Similar results can be obtained for any other implemented risk measure and type of optimization.
#
# We start by importing the **azapy** and other useful packages.

# %%
import numpy as np
import pandas as pd

import sys
sys.path.append("..")
import azapy as az

# %% [markdown]
# ### Collect historical market data for a set of portfolio components.
#
# - `symb` is the list of stock symbols (portfolio components).
# - `sdate` and `edate` are the start and end dates of historical time-series.
# - `mktdir` is the name of the directory used to save the market data collected from *alphavantage*.
#
# > Note: if the flag `force=False` then a reading from `dir=mktdir` is attempted. If it fails, then the *alphavantage* servers will be accessed. The new data will be saved to the `dir=mktdir` (*for more information see the readMkT documentation*).

# %%
symb = ['GLD', 'TLT', 'XLV', 'VGT', 'PSJ']

sdate = pd.to_datetime("2012-01-01")
edate = pd.to_datetime("today")

mktdir = "../MkTdata"

mktdata = az.readMkT(symb, dstart = sdate, dend = edate, dir=mktdir, force=False)
# Out:
# Read GLD form ../MkTdata
# Read TLT form ../MkTdata
# Read XLV form ../MkTdata
# Read VGT form ../MkTdata
# Read PSJ form ../MkTdata

# %% [markdown]
# ### Set the mixture of CVaR's parameters
#
# - `alpha` is the list of CVaR confidence levels,
# - `coef` is the list of CVaR's weights (coefficients).
#
# Note: `len(coef)=len(alpha)`. All the coefficients must be `>0`.

# %%
alpha = [0.95, 0.90, 0.85]
coef = [0.2, 0.3, 0.5]

# %% [markdown]
# ### Set the Port_CVaR class.
#
# For a full list of available setting parameters see the documentation.

# %%
pr1 = az.Port_CVaR(mktdata, pname='CVaRPort')

# %% [markdown]
# ### Set the model parameters
#
# > Note: This method must be called before any other. It will perform the main historical simulation.
#
# For a full list of available setting parameters see the documentation.

# %%
port = pr1.set_model(mu=0., alpha=alpha, coef=coef)

# %% [markdown]
# ### View the portfolio time-series
#
# For reference EMA for 30 and 200 business days were added *(default behavior)*.
#
# > Note the use of flag `fancy=True`. It designates the use of *plotly* package for interactive time-series.
#
# For a full list of available setting parameters see the documentation.

# %%
_ = pr1.port_view(fancy=True)
# Out:
# <div>                            <div id="d2c2bd02-30f1-4a22-a4b7-a3b16e50b393" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2c2bd02-30f1-4a22-a4b7-a3b16e50b393")) {                    Plotly.newPlot(                        "d2c2bd02-30f1-4a22-a4b7-a3b16e50b393",                        [{"line":{"width":1.5},"name":"CVaRPort","type":"scatter","x":["2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-22T00:00:00","2015-07-23T00:00:00","2015-07-24T00:00:00","2015-07-27T00:00:00","2015-07-28T00:00:00","2015-07-29T00:00:00","2015-07-30T00:00:00","2015-07-31T00:00:00","2015-08-03T00:00:00","2015-08-04T00:00:00","2015-08-05T00:00:00","2015-08-06T00:00:00","2015-08-07T00:00:00","2015-08-10T00:00:00","2015-08-11T00:00:00","2015-08-12T00:00:00","2015-08-13T00:00:00","2015-08-14T00:00:00","2015-08-17T00:00:00","2015-08-18T00:00:00","2015-08-19T00:00:00","2015-08-20T00:00:00","2015-08-21T00:00:00","2015-08-24T00:00:00","2015-08-25T00:00:00","2015-08-26T00:00:00","2015-08-27T00:00:00","2015-08-28T00:00:00","2015-08-31T00:00:00","2015-09-01T00:00:00","2015-09-02T00:00:00","2015-09-03T00:00:00","2015-09-04T00:00:00","2015-09-08T00:00:00","2015-09-09T00:00:00","2015-09-10T00:00:00","2015-09-11T00:00:00","2015-09-14T00:00:00","2015-09-15T00:00:00","2015-09-16T00:00:00","2015-09-17T00:00:00","2015-09-18T00:00:00","2015-09-21T00:00:00","2015-09-22T00:00:00","2015-09-23T00:00:00","2015-09-24T00:00:00","2015-09-25T00:00:00","2015-09-28T00:00:00","2015-09-29T00:00:00","2015-09-30T00:00:00","2015-10-01T00:00:00","2015-10-02T00:00:00","2015-10-05T00:00:00","2015-10-06T00:00:00","2015-10-07T00:00:00","2015-10-08T00:00:00","2015-10-09T00:00:00","2015-10-12T00:00:00","2015-10-13T00:00:00","2015-10-14T00:00:00","2015-10-15T00:00:00","2015-10-16T00:00:00","2015-10-19T00:00:00","2015-10-20T00:00:00","2015-10-21T00:00:00","2015-10-22T00:00:00","2015-10-23T00:00:00","2015-10-26T00:00:00","2015-10-27T00:00:00","2015-10-28T00:00:00","2015-10-29T00:00:00","2015-10-30T00:00:00","2015-11-02T00:00:00","2015-11-03T00:00:00","2015-11-04T00:00:00","2015-11-05T00:00:00","2015-11-06T00:00:00","2015-11-09T00:00:00","2015-11-10T00:00:00","2015-11-11T00:00:00","2015-11-12T00:00:00","2015-11-13T00:00:00","2015-11-16T00:00:00","2015-11-17T00:00:00","2015-11-18T00:00:00","2015-11-19T00:00:00","2015-11-20T00:00:00","2015-11-23T00:00:00","2015-11-24T00:00:00","2015-11-25T00:00:00","2015-11-27T00:00:00","2015-11-30T00:00:00","2015-12-01T00:00:00","2015-12-02T00:00:00","2015-12-03T00:00:00","2015-12-04T00:00:00","2015-12-07T00:00:00","2015-12-08T00:00:00","2015-12-09T00:00:00","2015-12-10T00:00:00","2015-12-11T00:00:00","2015-12-14T00:00:00","2015-12-15T00:00:00","2015-12-16T00:00:00","2015-12-17T00:00:00","2015-12-18T00:00:00","2015-12-21T00:00:00","2015-12-22T00:00:00","2015-12-23T00:00:00","2015-12-24T00:00:00","2015-12-28T00:00:00","2015-12-29T00:00:00","2015-12-30T00:00:00","2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00: ...

# %% [markdown]
# ### View the portfolio and its components time-series (in a relative bases)
#
# For a full list of available setting parameters see the documentation.

# %%
_ = pr1.port_view_all(fancy=True)
# Out:
# <div>                            <div id="5858b7a0-dd24-40ea-b726-55e9d838e275" class="plotly-graph-div" style="height:550px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5858b7a0-dd24-40ea-b726-55e9d838e275")) {                    Plotly.newPlot(                        "5858b7a0-dd24-40ea-b726-55e9d838e275",                        [{"line":{"width":1.5},"name":"GLD","type":"scatter","x":["2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00","2015-07-01T00:00:00","2015-07-02T00:00:00","2015-07-06T00:00:00","2015-07-07T00:00:00","2015-07-08T00:00:00","2015-07-09T00:00:00","2015-07-10T00:00:00","2015-07-13T00:00:00","2015-07-14T00:00:00","2015-07-15T00:00:00","2015-07-16T00:00:00","2015-07-17T00:00:00","2015-07-20T00:00:00","2015-07-21T00:00:00","2015-07-22T00:00:00","2015-07-23T00:00:00","2015-07-24T00:00:00","2015-07-27T00:00:00","2015-07-28T00:00:00","2015-07-29T00:00:00","2015-07-30T00:00:00","2015-07-31T00:00:00","2015-08-03T00:00:00","2015-08-04T00:00:00","2015-08-05T00:00:00","2015-08-06T00:00:00","2015-08-07T00:00:00","2015-08-10T00:00:00","2015-08-11T00:00:00","2015-08-12T00:00:00","2015-08-13T00:00:00","2015-08-14T00:00:00","2015-08-17T00:00:00","2015-08-18T00:00:00","2015-08-19T00:00:00","2015-08-20T00:00:00","2015-08-21T00:00:00","2015-08-24T00:00:00","2015-08-25T00:00:00","2015-08-26T00:00:00","2015-08-27T00:00:00","2015-08-28T00:00:00","2015-08-31T00:00:00","2015-09-01T00:00:00","2015-09-02T00:00:00","2015-09-03T00:00:00","2015-09-04T00:00:00","2015-09-08T00:00:00","2015-09-09T00:00:00","2015-09-10T00:00:00","2015-09-11T00:00:00","2015-09-14T00:00:00","2015-09-15T00:00:00","2015-09-16T00:00:00","2015-09-17T00:00:00","2015-09-18T00:00:00","2015-09-21T00:00:00","2015-09-22T00:00:00","2015-09-23T00:00:00","2015-09-24T00:00:00","2015-09-25T00:00:00","2015-09-28T00:00:00","2015-09-29T00:00:00","2015-09-30T00:00:00","2015-10-01T00:00:00","2015-10-02T00:00:00","2015-10-05T00:00:00","2015-10-06T00:00:00","2015-10-07T00:00:00","2015-10-08T00:00:00","2015-10-09T00:00:00","2015-10-12T00:00:00","2015-10-13T00:00:00","2015-10-14T00:00:00","2015-10-15T00:00:00","2015-10-16T00:00:00","2015-10-19T00:00:00","2015-10-20T00:00:00","2015-10-21T00:00:00","2015-10-22T00:00:00","2015-10-23T00:00:00","2015-10-26T00:00:00","2015-10-27T00:00:00","2015-10-28T00:00:00","2015-10-29T00:00:00","2015-10-30T00:00:00","2015-11-02T00:00:00","2015-11-03T00:00:00","2015-11-04T00:00:00","2015-11-05T00:00:00","2015-11-06T00:00:00","2015-11-09T00:00:00","2015-11-10T00:00:00","2015-11-11T00:00:00","2015-11-12T00:00:00","2015-11-13T00:00:00","2015-11-16T00:00:00","2015-11-17T00:00:00","2015-11-18T00:00:00","2015-11-19T00:00:00","2015-11-20T00:00:00","2015-11-23T00:00:00","2015-11-24T00:00:00","2015-11-25T00:00:00","2015-11-27T00:00:00","2015-11-30T00:00:00","2015-12-01T00:00:00","2015-12-02T00:00:00","2015-12-03T00:00:00","2015-12-04T00:00:00","2015-12-07T00:00:00","2015-12-08T00:00:00","2015-12-09T00:00:00","2015-12-10T00:00:00","2015-12-11T00:00:00","2015-12-14T00:00:00","2015-12-15T00:00:00","2015-12-16T00:00:00","2015-12-17T00:00:00","2015-12-18T00:00:00","2015-12-21T00:00:00","2015-12-22T00:00:00","2015-12-23T00:00:00","2015-12-24T00:00:00","2015-12-28T00:00:00","2015-12-29T00:00:00","2015-12-30T00:00:00","2015-12-31T00:00:00","2016-01-04T00:00:00","2016-01-05T00:00:00","2016-01-06T00:00:00","2016-01-07T00:00:00","2016-01-08T00:00:00","2016-01-11T00:00:00","2016-01-12T00:00:00","2016-01-13T00:00:00","2016-01-14T00:00:00","2016-01-15T00:00:00","2016-01-19T00:00:00","2016-01-20T00:00:00","2016-01-21T00:00:00","2016-01-22T00:00:00","2016-01-25T00:00:00","2016-01-26T00:00:00","2016-01-27T00:00:00","2016-01-28T00:00:00","2016-01-29T00:00:00","2016-02-01T00:00:00","2016-02-02T00:00:00","2016-02-03T00:00:00","2016-02-04T00:00:00"," ...

# %% [markdown]
# ### Portfolio weights for each rebalancing period
#
# - `Droll` is the rolling date. The new positions are acquired at the end of trading day (theoretically at the closing price).
# - `Dfix` is the fixing date relative to which the weights are computed. This is also the last closing prices included in the evaluation of the weights.
# - `Dhist` this is the earliest date included in the calibration of weights. The hist data used in the calibration is between and including the `Dhist` and `Dfix`.
#
# > Note the use of flag `fancy=True` - the weights are reported in percent with 2 decimals.
#
# For a full list of available setting parameters see the documentation.

# %%
pr1.get_weights(fancy=True)
# Out:
#         Droll       Dfix      Dhist    GLD    PSJ    TLT    VGT    XLV
# 0  2015-06-25 2015-06-24 2012-03-23   0.00   0.00  10.74   0.00  89.26
# 1  2015-09-25 2015-09-24 2012-06-22   0.00   0.00  13.12   0.00  86.88
# 2  2015-12-28 2015-12-24 2012-09-24   0.00  35.48  34.84  11.61  18.07
# 3  2016-03-28 2016-03-24 2012-12-24   0.00   0.39  40.35  21.04  38.22
# 4  2016-06-27 2016-06-24 2013-03-22   0.00  16.09  42.00  12.00  29.92
# 5  2016-09-27 2016-09-26 2013-06-26   0.00  22.59  48.18   4.66  24.56
# 6  2016-12-27 2016-12-23 2013-09-23   0.00   0.00  38.86  61.14   0.00
# 7  2017-03-28 2017-03-27 2013-12-27   0.00   0.00  36.89  63.11   0.00
# 8  2017-06-27 2017-06-26 2014-03-26   0.00   0.00  36.02  63.98   0.00
# 9  2017-09-26 2017-09-25 2014-06-25   0.00   6.08  35.82  58.11   0.00
# 10 2017-12-26 2017-12-22 2014-09-22   0.00   9.56  34.53  55.91   0.00
# 11 2018-03-26 2018-03-23 2014-12-23   0.00   0.00  32.32  67.68   0.00
# 12 2018-06-26 2018-06-25 2015-03-25   0.00  10.52  33.08  56.41   0.00
# 13 2018-09-25 2018-09-24 2015-06-24   0.00   0.00  32.20  67.80   0.00
# 14 2018-12-26 2018-12-24 2015-09-24  32.85   0.00   0.00  64.19   2.96
# 15 2019-03-26 2019-03-25 2015-12-24  16.12  76.41   0.00   0.00   7.47
# 16 2019-06-25 2019-06-24 2016-03-24   6.37  93.63   0.00   0.00   0.00
# 17 2019-09-25 2019-09-24 2016-06-24  25.92  47.52   0.00  26.55   0.00
# 18 2019-12-26 2019-12-24 2016-09-23  49.74  19.28   0.00  16.93  14.04
# 19 2020-03-26 2020-03-25 2016-12-23  43.72   5.85  23.65  11.38  15.40
# 20 2020-06-25 2020-06-24 2017-03-24  43.01   5.85  24.84  10.60  15.70
# 21 2020-09-25 2020-09-24 2017-06-23  44.66   5.24  23.23  12.54  14.33
# 22 2020-12-28 2020-12-24 2017-09-22  48.86  18.13  15.39   2.68  14.94
# 23 2021-03-26 2021-03-25 2017-12-22  55.00  27.40   7.43   0.00  10.18
# 24 2021-06-25 2021-06-24 2018-03-23  49.81   9.28   6.87  14.97  19.06
# 25 2021-09-27 2021-09-24 2018-06-22    NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# ### Portfolio performance
#
# Reports the portfolio and its components performance for the duration of the investment.
#
# - `RR` is the portfolio average annual rate of returns.
# - `DD` is the maximum drawdown rate.
# - `Beta` is the ratio `RR/DD`.
# - `DD_date` is the date of maximum drawdown.
# - `DD_start` is the date when the maximum drawdown event had started.
# - `DD_end` is the date when the maximum drawdown event had ended. If it is `Nan`, then the drawdown is still in progress (`DD` and `DD_date` are only provisional).
#
# > Note the use of flag `fancy=True` - the rates are reported in percent with 2 decimals.

# %%
pr1.port_perf(fancy=True)
# Out:
#              RR     DD      Beta     DD_date    DD_start      DD_end
# symbol
# CVaRPort   9.75 -18.30  0.532649  2020-03-20  2020-02-19  2020-06-23
# VGT       23.24 -31.86  0.729357  2020-03-23  2020-02-19  2020-06-09
# PSJ       22.12 -30.69  0.720979  2020-03-16  2020-02-19  2020-05-22
# XLV       16.74 -28.39  0.589717  2020-03-23  2020-01-22  2020-07-15
# TLT        4.92 -21.34  0.230336  2021-03-18  2020-08-04         NaN
# GLD        0.81 -42.11  0.019280  2015-12-17  2012-10-04  2020-07-22

# %% [markdown]
# ### Portfolio drawdowns
#
# Reports the largest drawdown events. The default is the first 5.
#
# > Note the use of flag fancy=True - the rates are reported in percent with 2 decimals.
#
# For a full list of available setting parameters see the documentation.

# %%
pr1.port_drawdown(fancy=True)
# Out:
#        DD        Date       Start         End
# No
# 1  -18.30  2020-03-20  2020-02-19  2020-06-23
# 2  -15.73  2018-12-24  2018-08-31  2019-02-25
# 3  -14.62  2015-09-28  2015-08-05  2016-06-02
# 4  -10.58  2021-03-08  2020-08-06         NaN
# 5   -9.91  2019-10-22  2019-07-26  2020-01-03

# %% [markdown]
# ### Portfolio annual returns
#
# Annual returns are per calendar year (1 Jan to 31 Dec). If the first or last years are incomplete, then the rates are reported per invested period in the respective years.
#
# > Note the use of flag fancy=True - the rates are reported in percent with 2 decimals.

# %%
pr1.port_annual_returns(fancy=True)
# Out:
# <style type="text/css">
# #T_1710f_row0_col0, #T_1710f_row6_col0 {
#   color: red;
# }
# #T_1710f_row1_col0, #T_1710f_row2_col0, #T_1710f_row3_col0, #T_1710f_row4_col0, #T_1710f_row5_col0 {
#   color: black;
# }
# </style>
# <table id="T_1710f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CVaRPort</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1710f_level0_row0" class="row_heading level0 row0" >2015</th>
#       <td id="T_1710f_row0_col0" class="data row0 col0" >-2.17%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row1" class="row_heading level0 row1" >2016</th>
#       <td id="T_1710f_row1_col0" class="data row1 col0" >1.30%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row2" class="row_heading level0 row2" >2017</th>
#       <td id="T_1710f_row2_col0" class="data row2 col0" >26.06%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row3" class="row_heading level0 row3" >2018</th>
#       <td id="T_1710f_row3_col0" class="data row3 col0" >0.28%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row4" class="row_heading level0 row4" >2019</th>
#       <td id="T_1710f_row4_col0" class="data row4 col0" >24.15%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row5" class="row_heading level0 row5" >2020</th>
#       <td id="T_1710f_row5_col0" class="data row5 col0" >11.88%</td>
#     </tr>
#     <tr>
#       <th id="T_1710f_level0_row6" class="row_heading level0 row6" >2021</th>
#       <td id="T_1710f_row6_col0" class="data row6 col0" >-0.15%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Portfolio monthly returns
#
# Same as above but per calendar month of each year. This are simple monthly rates.
#
# > Note the use of flag fancy=True - the rates are reported in percent with 2 decimals.

# %%
pr1.port_monthly_returns(fancy=True)
# Out:
# <style type="text/css">
# #T_17129_row0_col0, #T_17129_row0_col2, #T_17129_row0_col3, #T_17129_row0_col4, #T_17129_row0_col5, #T_17129_row1_col0, #T_17129_row1_col1, #T_17129_row1_col2, #T_17129_row1_col4, #T_17129_row2_col0, #T_17129_row2_col1, #T_17129_row2_col2, #T_17129_row2_col3, #T_17129_row3_col0, #T_17129_row3_col2, #T_17129_row3_col3, #T_17129_row3_col4, #T_17129_row3_col5, #T_17129_row3_col6, #T_17129_row4_col0, #T_17129_row4_col1, #T_17129_row4_col2, #T_17129_row4_col3, #T_17129_row4_col5, #T_17129_row4_col6, #T_17129_row5_col1, #T_17129_row5_col4, #T_17129_row6_col0, #T_17129_row6_col1, #T_17129_row6_col2, #T_17129_row6_col3, #T_17129_row6_col4, #T_17129_row6_col5, #T_17129_row6_col6, #T_17129_row7_col2, #T_17129_row7_col3, #T_17129_row7_col6, #T_17129_row8_col1, #T_17129_row8_col2, #T_17129_row8_col6, #T_17129_row9_col0, #T_17129_row9_col2, #T_17129_row9_col4, #T_17129_row9_col6, #T_17129_row10_col2, #T_17129_row10_col4, #T_17129_row10_col5, #T_17129_row10_col6, #T_17129_row11_col0, #T_17129_row11_col1, #T_17129_row11_col2, #T_17129_row11_col4, #T_17129_row11_col5, #T_17129_row11_col6 {
#   color: black;
# }
# #T_17129_row0_col1, #T_17129_row0_col6, #T_17129_row1_col3, #T_17129_row1_col5, #T_17129_row1_col6, #T_17129_row2_col4, #T_17129_row2_col5, #T_17129_row2_col6, #T_17129_row3_col1, #T_17129_row4_col4, #T_17129_row5_col0, #T_17129_row5_col2, #T_17129_row5_col3, #T_17129_row5_col5, #T_17129_row5_col6, #T_17129_row7_col0, #T_17129_row7_col1, #T_17129_row7_col4, #T_17129_row7_col5, #T_17129_row8_col0, #T_17129_row8_col3, #T_17129_row8_col4, #T_17129_row8_col5, #T_17129_row9_col1, #T_17129_row9_col3, #T_17129_row9_col5, #T_17129_row10_col0, #T_17129_row10_col1, #T_17129_row10_col3, #T_17129_row11_col3 {
#   color: red;
# }
# </style>
# <table id="T_17129_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="col_heading level0 col0" >2015</th>
#       <th class="col_heading level0 col1" >2016</th>
#       <th class="col_heading level0 col2" >2017</th>
#       <th class="col_heading level0 col3" >2018</th>
#       <th class="col_heading level0 col4" >2019</th>
#       <th class="col_heading level0 col5" >2020</th>
#       <th class="col_heading level0 col6" >2021</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17129_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_17129_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_17129_row0_col1" class="data row0 col1" >-1.66%</td>
#       <td id="T_17129_row0_col2" class="data row0 col2" >2.27%</td>
#       <td id="T_17129_row0_col3" class="data row0 col3" >3.37%</td>
#       <td id="T_17129_row0_col4" class="data row0 col4" >6.27%</td>
#       <td id="T_17129_row0_col5" class="data row0 col5" >1.78%</td>
#       <td id="T_17129_row0_col6" class="data row0 col6" >-2.03%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_17129_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_17129_row1_col1" class="data row1 col1" >1.41%</td>
#       <td id="T_17129_row1_col2" class="data row1 col2" >3.44%</td>
#       <td id="T_17129_row1_col3" class="data row1 col3" >-0.23%</td>
#       <td id="T_17129_row1_col4" class="data row1 col4" >4.31%</td>
#       <td id="T_17129_row1_col5" class="data row1 col5" >-3.54%</td>
#       <td id="T_17129_row1_col6" class="data row1 col6" >-3.92%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_17129_row2_col0" class="data row2 col0" >nan%</td>
#       <td id="T_17129_row2_col1" class="data row2 col1" >1.59%</td>
#       <td id="T_17129_row2_col2" class="data row2 col2" >0.81%</td>
#       <td id="T_17129_row2_col3" class="data row2 col3" >0.27%</td>
#       <td id="T_17129_row2_col4" class="data row2 col4" >-0.71%</td>
#       <td id="T_17129_row2_col5" class="data row2 col5" >-6.60%</td>
#       <td id="T_17129_row2_col6" class="data row2 col6" >-2.25%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_17129_row3_col0" class="data row3 col0" >nan%</td>
#       <td id="T_17129_row3_col1" class="data row3 col1" >-0.86%</td>
#       <td id="T_17129_row3_col2" class="data row3 col2" >1.87%</td>
#       <td id="T_17129_row3_col3" class="data row3 col3" >0.89%</td>
#       <td id="T_17129_row3_col4" class="data row3 col4" >3.02%</td>
#       <td id="T_17129_row3_col5" class="data row3 col5" >8.80%</td>
#       <td id="T_17129_row3_col6" class="data row3 col6" >2.26%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_17129_row4_col0" class="data row4 col0" >nan%</td>
#       <td id="T_17129_row4_col1" class="data row4 col1" >2.36%</td>
#       <td id="T_17129_row4_col2" class="data row4 col2" >3.22%</td>
#       <td id="T_17129_row4_col3" class="data row4 col3" >4.71%</td>
#       <td id="T_17129_row4_col4" class="data row4 col4" >-2.92%</td>
#       <td id="T_17129_row4_col5" class="data row4 col5" >3.37%</td>
#       <td id="T_17129_row4_col6" class="data row4 col6" >2.91%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_17129_row5_col0" class="data row5 col0" >-1.92%</td>
#       <td id="T_17129_row5_col1" class="data row5 col1" >2.60%</td>
#       <td id="T_17129_row5_col2" class="data row5 col2" >-1.79%</td>
#       <td id="T_17129_row5_col3" class="data row5 col3" >-3.49%</td>
#       <td id="T_17129_row5_col4" class="data row5 col4" >7.39%</td>
#       <td id="T_17129_row5_col5" class="data row5 col5" >-0.50%</td>
#       <td id="T_17129_row5_col6" class="data row5 col6" >-2.39%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_17129_row6_col0" class="data row6 col0" >2.30%</td>
#       <td id="T_17129_row6_col1" class="data row6 col1" >3.43%</td>
#       <td id="T_17129_row6_col2" class="data row6 col2" >3.06%</td>
#       <td id="T_17129_row6_col3" class="data row6 col3" >0.42%</td>
#       <td id="T_17129_row6_col4" class="data row6 col4" >4.82%</td>
#       <td id="T_17129_row6_col5" class="data row6 col5" >7.57%</td>
#       <td id="T_17129_row6_col6" class="data row6 col6" >1.60%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_17129_row7_col0" class="data row7 col0" >-7.20%</td>
#       <td id="T_17129_row7_col1" class="data row7 col1" >-0.62%</td>
#       <td id="T_17129_row7_col2" class="data row7 col2" >2.61%</td>
#       <td id="T_17129_row7_col3" class="data row7 col3" >6.20%</td>
#       <td id="T_17129_row7_col4" class="data row7 col4" >-3.87%</td>
#       <td id="T_17129_row7_col5" class="data row7 col5" >-0.07%</td>
#       <td id="T_17129_row7_col6" class="data row7 col6" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_17129_row8_col0" class="data row8 col0" >-2.93%</td>
#       <td id="T_17129_row8_col1" class="data row8 col1" >0.10%</td>
#       <td id="T_17129_row8_col2" class="data row8 col2" >1.71%</td>
#       <td id="T_17129_row8_col3" class="data row8 col3" >-0.89%</td>
#       <td id="T_17129_row8_col4" class="data row8 col4" >-1.82%</td>
#       <td id="T_17129_row8_col5" class="data row8 col5" >-3.56%</td>
#       <td id="T_17129_row8_col6" class="data row8 col6" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_17129_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_17129_row9_col0" class="data row9 col0" >5.62%</td>
#       <td id="T_17129_row9_col1" class="data row9 col1" >-4.22%</td>
#       <td id="T_17

# %% [markdown]
# ### Portfolio returns per rolling period
#
# Additional reference info is included in the report.
#
# - `Droll` is the rolling date. Identifies the start of the rolling period, (Droll, next Droll].
# - `Dfix` is the fixing date.
# - `RR` simple rate of return per rolling period.
# - portfolio weights for each rolling period.
#
# > Note the use of flag fancy=True - the rates are reported in percent with 2 decimals.

# %%
pr1.port_period_returns(fancy=True)
# Out:
#         Droll       Dfix     RR    GLD    TLT    XLV    VGT    PSJ
# 0  2015-06-25 2015-06-24 -10.38   0.00  10.74  89.26   0.00   0.00
# 1  2015-09-25 2015-09-24  10.34   0.00  13.12  86.88   0.00   0.00
# 2  2015-12-28 2015-12-24  -1.18   0.00  34.84  18.07  11.61  35.48
# 3  2016-03-28 2016-03-24   2.98   0.00  40.35  38.22  21.04   0.39
# 4  2016-06-27 2016-06-24   7.08   0.00  42.00  29.92  12.00  16.09
# 5  2016-09-27 2016-09-26  -8.61   0.00  48.18  24.56   4.66  22.59
# 6  2016-12-27 2016-12-23   6.71   0.00  38.86   0.00  61.14   0.00
# 7  2017-03-28 2017-03-27   5.20   0.00  36.89   0.00  63.11   0.00
# 8  2017-06-27 2017-06-26   5.17   0.00  36.02   0.00  63.98   0.00
# 9  2017-09-26 2017-09-25   6.43   0.00  35.82   0.00  58.11   6.08
# 10 2017-12-26 2017-12-22   3.69   0.00  34.53   0.00  55.91   9.56
# 11 2018-03-26 2018-03-23   1.13   0.00  32.32   0.00  67.68   0.00
# 12 2018-06-26 2018-06-25   6.06   0.00  33.08   0.00  56.41  10.52
# 13 2018-09-25 2018-09-24 -10.53   0.00  32.20   0.00  67.80   0.00
# 14 2018-12-26 2018-12-24  11.77  32.85   0.00   2.96  64.19   0.00
# 15 2019-03-26 2019-03-25   3.35  16.12   0.00   7.47   0.00  76.41
# 16 2019-06-25 2019-06-24   2.08   6.37   0.00   0.00   0.00  93.63
# 17 2019-09-25 2019-09-24   7.17  25.92   0.00   0.00  26.55  47.52
# 18 2019-12-26 2019-12-24  -4.29  49.74   0.00  14.04  16.93  19.28
# 19 2020-03-26 2020-03-25   8.41  43.72  23.65  15.40  11.38   5.85
# 20 2020-06-25 2020-06-24   4.51  43.01  24.84  15.70  10.60   5.85
# 21 2020-09-25 2020-09-24   3.04  44.66  23.23  14.33  12.54   5.24
# 22 2020-12-28 2020-12-24  -4.44  48.86  15.39  14.94   2.68  18.13
# 23 2021-03-26 2021-03-25   3.97  55.00   7.43  10.18   0.00  27.40
# 24 2021-06-25 2021-06-24   1.97  49.81   6.87  19.06  14.97   9.28

# %% [markdown]
# ### Number of shares invested at each rebalancing period

# %%
pr1.get_nshares()
# Out:
#             GLD   PSJ  TLT  VGT   XLV
# Droll
# 2015-06-25    0     0   92    0  1179
# 2015-09-25    0     0   99    0  1166
# 2015-12-28    0   823  284  105   248
# 2016-03-28    0     9  306  193   557
# 2016-06-27    0   381  313  116   437
# 2016-09-27    0   504  376   42   365
# 2016-12-27    0     0  325  490     0
# 2017-03-28    0     0  320  495     0
# 2017-06-27    0     0  316  499     0
# 2017-09-26    0   117  329  455     0
# 2017-12-26    0   187  345  419     0
# 2018-03-26    0     0  338  505     0
# 2018-06-26    0   180  355  403     0
# 2018-09-25    0     0  381  465     0
# 2018-12-26  326     0    0  493    44
# 2019-03-26  178  1166    0    0   114
# 2019-06-25   69  1426    0    0     0
# 2019-09-25  261   744    0  180     0
# 2019-12-26  547   298    0  108   212
# 2020-03-26  420   106  212   81   275
# 2020-06-25  418    84  246   63   259
# 2020-09-25  429    75  237   71   238
# 2020-12-28  487   199  172   13   236
# 2021-03-26  564   297   90    0   147
# 2021-06-25  519    97   83   66   264

# %% [markdown]
# ### Additional accounting information
#
# Additional accounting information per rebalancing period.
#
# - `Droll` rolling date. It identifies the rebalancing period.
# - Invested number of shares per portfolio component
# - `cash_invst` is the dollar value of the invested shares at the beginning of rebalancing period (using closing prices in the `Droll` date).
# - `cash_roll` amount of cash rolled to next period. The source of this cash is twofold. First due to rounding to an integer number of shares and second due to price slippage between the weights computation time, `Dfix` date, and the execution (buy/sale) of the portfolio positions, `Droll` date. It can be positive or negative. In both cases it is a small value relative to the invested capital. It is the investor obligation to make the shortfall until next rolling date.
# - `cash_divd` is the amount of cash collected during the rebalancing period. It will be part of the investor capital in the next period.

# %%
pr1.get_account(fancy=True)
# Out:
#             GLD   PSJ  TLT  VGT   XLV  cash_invst  cash_roll  cash_divd
# Droll
# 2015-06-25    0     0   92    0  1179   100443.58    -443.58       0.00
# 2015-09-25    0     0   99    0  1166    90014.54    2269.01     379.89
# 2015-12-28    0   823  284  105   248    99318.01     -55.76     455.37
# 2016-03-28    0     9  306  193   557    98147.26     112.80     240.43
# 2016-06-27    0   381  313  116   437   101067.91     248.58     470.56
# 2016-09-27    0   504  376   42   365   108222.71    -767.40     408.68
# 2016-12-27    0     0  325  490     0    98899.85    -257.99     531.23
# 2017-03-28    0     0  320  495     0   105532.30    -185.31     338.13
# 2017-06-27    0     0  316  499     0   111020.11    1642.15     247.17
# 2017-09-26    0   117  329  455     0   116762.66    -218.72     451.89
# 2017-12-26    0   187  345  419     0   124269.76     432.07     728.94
# 2018-03-26    0     0  338  505     0   128852.13   -3115.07     328.51
# 2018-06-26    0   180  355  403     0   130310.66    -630.90     271.58
# 2018-09-25    0     0  381  465     0   138203.73      26.61     747.02
# 2018-12-26  326     0    0  493    44   123645.72   -4698.54     711.00
# 2019-03-26  178  1166    0    0   114   138195.64    -316.19     309.22
# 2019-06-25   69  1426    0    0     0   142818.96    3025.45      45.42
# 2019-09-25  261   744    0  180     0   145788.63    -473.45       0.00
# 2019-12-26  547   298    0  108   212   156242.91    -973.70     305.37
# 2020-03-26  420   106  212   81   275   149542.84   -4123.03     329.65
# 2020-06-25  418    84  246   63   259   162112.41    -781.81     312.32
# 2020-09-25  429    75  237   71   238   169416.02   -1060.30     291.85
# 2020-12-28  487   199  172   13   236   174561.93    1215.83     317.20
# 2021-03-26  564   297   90    0   147   166816.95    -974.42     153.58
# 2021-06-25  519    97   83   66   264   173441.19    -352.18     123.55
